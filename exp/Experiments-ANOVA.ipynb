# %% [markdown]
# The only variable you need to adjust: conf_index
# 1. CNN Models
# 2. Transformer
# 3. Transformer(Qwen3 0.6B $ Pythia 1B)
#
# After selecting a right index, just run all
#
# Experiment 1 and 2 may take more than 3 or 4 days to run

# %%
conf_index = 2

# %%
import logging
from pathlib import Path
from exp.run import ExperimentRun, SummarySectionName
from exp.config import TransformerExperiments, CNNExperiments, LargeTransformerExperiments
logging.basicConfig(level=logging.ERROR)
# Out:
# /home/glaswegian/miniconda3/envs/xmem-test/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
configures = [
	CNNExperiments(),
	TransformerExperiments(),
	LargeTransformerExperiments()
]
config = configures[conf_index]
print(f"All results will be saved in {Path().home().joinpath(config.run_id)}")
# Out:
# All results will be saved in /home/glaswegian/Large-Transformer-Exp

# %%
config.debug = False
config.repeats = 5
config.gpu_id = 1
exp = ExperimentRun(config=config)

# %%
exp.run_anova_experiments()
exp.to_evaluation_result()
# Out:
# PyTorch version: 2.6.0+cpu
# PyTorch built with CUDA version: None
# CUDA version: False
# CUDA device count: 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 exp.run_anova_experiments()
#       2 exp.to_evaluation_result()
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:615, in ExperimentRun.run_anova_experiments(self)
#     613 self.basic_info()
#     614 self._job_list: list[_ExperimentExecutor] = []
# --> 615 self.prepare_regular_experiments_data()
#     616 print(f"{'='*10} ANOVA Experiment #{len(self._job_list)} runs {'='*10}")
#     617 if isinstance(self._config, LargeTransformerExperiments):
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:473, in ExperimentRun.prepare_regular_experiments_data(self)
#     469 for batch_number in range(
#     470     conf.batch_range[0], conf.batch_range[1], conf.batch_range[2]
#     471 ):
#     472     for i in range(conf.repeats):
# --> 473         self.add_task(
#     474             model_name=model,
#     475             batch_size=batch_number,
#     476             optimizer=opt,
#     477             gpu_id=gpu_id,
#     478         )
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:452, in ExperimentRun.add_task(self, model_name, batch_size, optimizer, gpu_id, zero_out, task_id)
#     449 _exe_config.trainer.bf16 = self._config.bf16
#     450 _exe_config.debug = self._config.debug
# --> 452 _exe_instance = _ExperimentExecutor(
#     453     model_name=model_name,
#     454     batch_size=batch_size,
#     455     optimizer=optimizer,
#     456     gpu_id=gpu_id,
#     457     config=_exe_config,
#     458 )
#     459 self._job_list.append(_exe_instance)
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:63, in _ExperimentExecutor.__init__(self, model_name, batch_size, optimizer, gpu_id, config)
#      54 def __init__(
#      55     self,
#      56     model_name: str,
#    (...)     60     config: Config,
#      61 ):
#      62     if not torch.cuda.is_available():
# ---> 63         raise RuntimeError(
#      64             f"CUDA is not available. CUDA is mandatory for this experiment."
#      65         )
#      66     else:
#      67         gpu_info = torch.cuda.get_device_properties(gpu_id)
#
# RuntimeError: CUDA is not available. CUDA is mandatory for this experiment.
