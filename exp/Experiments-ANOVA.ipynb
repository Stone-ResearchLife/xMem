# %% [markdown]
# The only variable you need to adjust: conf_index
# 1. CNN Models
# 2. Transformer
# 3. Transformer(Qwen3 0.6B $ Pythia 1B)
#
# After selecting a right index, just run all
#
# Experiment 1 and 2 may take more than 3 or 4 days to run

# %%
conf_index = 1

# %%
import logging
from pathlib import Path
from exp.run import ExperimentRun, SummarySectionName
from exp.config import TransformerExperiments, CNNExperiments, LargeTransformerExperiments
logging.basicConfig(level=logging.ERROR)

# %%
configures = [
	CNNExperiments(),
	TransformerExperiments(),
	LargeTransformerExperiments()
]
config = configures[conf_index]
print(f"All results will be saved in {Path().home().joinpath(config.run_id)}")
# Out:
# All results will be saved in /home/glaswegian/Transformer-Exp

# %%
config.debug = False
config.repeats = 1
config.gpu_id = 1
config.result_verification = True
exp = ExperimentRun(config=config)

# %%
exp.run_anova_experiments()
results = exp.to_evaluation_result()
# Out:
# PyTorch version: 2.6.0+cu124
# PyTorch built with CUDA version: 12.4
# CUDA version: True
# CUDA device count: 2
# ========== ANOVA Experiment #11 runs ==========
# 100%|██████████| 11/11 [00:00<00:00, 49.55it/s]
# =============== Start massively run for GPU train ======================
# 100%|██████████| 11/11 [16:53<00:00, 92.14s/it]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ================== Create docker containers ==================
# 100%|██████████| 11/11 [00:22<00:00,  2.05s/it]
# ================== Execute docker containers ==================
# =============== Start massively run for GPU train ======================
# 100%|██████████| 11/11 [07:12<00:00, 39.35s/it]
#   9%|▉         | 1/11 [1:36:28<16:04:48, 5788.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 exp.run_anova_experiments()
#       2 results = exp.to_evaluation_result()
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:620, in ExperimentRun.run_anova_experiments(self)
#     618     self.run_experiments_solving_compatibility_issue()
#     619 else:
# --> 620     self.run_experiments()
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:627, in ExperimentRun.run_experiments(self)
#     625 if isinstance(self._config, TransformerExperiments):
#     626     est_list.append(SummarySectionName.LLmem)
# --> 627 self.run_estimation(estimators=est_list, in_docker=True)
#     628 if isinstance(self._config, TransformerExperiments):
#     629     self.verify_llmem_result()
#
# File ~/Documents/100-repo/200-xmem/exp/run.py:698, in ExperimentRun.run_estimation(self, estimators, force, in_docker)
#     696     time.sleep(2)
#     697 print("================== Execute docker containers ==================")
# --> 698 exp.execute(manual_container=True)
#     699 print("================== Statistics ==================")
#     700 print(
#     701     f"Run(success/total): {len([(int(cont.exit_code) == 0) is True for cont in containers])}/{len(containers)}"
#     702 )
#
# File ~/Documents/100-repo/200-xmem/paper_container/evaluations.py:208, in Experiments.execute(self, model, batch, optimizer, gpu_id, task_id, is_transformer, dnnmem, llmem, schedtune, paper, manual_container)
#     195 if manual_container is False:
#     196     self.add_container(
#     197         model=model,
#     198         batch=batch,
#    (...)    206         paper=paper,
#     207     )
# --> 208 self._execute()
#
# File ~/Documents/100-repo/200-xmem/paper_container/evaluations.py:178, in Experiments._execute(self, **kwargs)
#     174 print(
#     175     f"=============== Start massively run for GPU train ======================"
#     176 )
#     177 self._containers.run()
# --> 178 self._schedtune_containers.run()
#     179 self._llmem_containers.run()
#
# File ~/miniconda3/envs/xmem-exp/lib/python3.11/site-packages/ures/docker/containers.py:231, in Containers.run(self)
#     229 containers = [_c[1]["container"] for _c in new_containers]
#     230 _runtime = self._runtime(containers=containers)
# --> 231 _runtime.run()
#     232 return new_containers
#
# File ~/Documents/100-repo/200-xmem/paper_container/evaluations.py:36, in EvaluateRuntime.run(self, *args, **kwargs)
#      34 start_time = time.time()
#      35 while container.is_running:
# ---> 36     time.sleep(5)
#      37     c_time = time.time()
#      38     if c_time - start_time > timeout:
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualize the Results

# %%
from pathlib import Path
from plot.plot import ExperimentPlot, DataAggregation
e_plot = ExperimentPlot()
src_dir = Path().home().joinpath(config.run_id)

# %%
da = DataAggregation(random_dir=False)
result_dir = da.aggregate(src_dir, subdir_name="ANOVA")
print(f"All results will be copied to {result_dir}")

# %% [markdown]
# ## MER

# %%
filename = "ViewOnly-ANOVA-MER"
print(f"The Box Plot below shows result for CNN models from ANOVA. ")
fig = e_plot.plot_relative_error_in_box_diagram_with_verification_data(
    title=filename,
    data_dir=result_dir,
    overall_median=False,
    view_mode = True,
)
fig.show()

# %% [markdown]
# ## PEF

# %%
filename = "ViewOnly-ANOVA-PEF"
fig = e_plot.plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title=filename,
    data_dir=result_dir,
    view_mode=True
)
fig.show()
