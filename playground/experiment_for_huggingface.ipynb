# %%
from perf_estimator.profiler import ProfilerDataProcessing
from perf_estimator.estimator import Estimator

# %%
profiler  = ProfilerDataProcessing("../examples/test-1.json")
# Out:
# Duplicate layer name found: Resize_0. Renaming to Resize_0_15
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_f0
# Duplicate layer name found: Resize_0. Renaming to Resize_0_ff
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_5b
# Duplicate layer name found: Resize_0. Renaming to Resize_0_52
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_3b
# Duplicate layer name found: Resize_0. Renaming to Resize_0_9f
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_f8
# Duplicate layer name found: Resize_0. Renaming to Resize_0_4a
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_e2
# Duplicate layer name found: Resize_0. Renaming to Resize_0_74
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_70
# Duplicate layer name found: Resize_0. Renaming to Resize_0_3a
# Duplicate layer name found: Normalize_0. Renaming to Normalize_0_cd
# ...

# %%
second_iter = profiler.get_iteration(2)
first_iter = profiler.get_iteration(1)

# %%
first_iter.layer_summary()
# Out:
# [{'name': 'Resize_0',
#   'start': 3125168269070.421,
#   'end': 3125168269195.4,
#   'forward_memory': [],
#   'backward_memory': []},
#  {'name': 'Normalize_0',
#   'start': 3125168269399.086,
#   'end': 3125168269508.3667,
#   'forward_memory': [Memory(other|823247680|free): Bytes:88752, Start:3125168269423.755, End:3125168281717.531, Comments: ],
#   'backward_memory': [Memory(other|1651333312|free): Bytes:37632, Start:3125168981111.681, End:3125169046034.059, Comments: ,
#    Memory(other|1360153536|persis): Bytes:5680128, Start:3125168281229.289, End:None, Comments: ]},
#  {'name': 'Resize_0_15',
#   'start': 3125168269552.09,
#   'end': 3125168269624.4,
#   'forward_memory': [],
#   'backward_memory': []},
#  {'name': 'Normalize_0_f0',
#   'start': 3125168274316.981,
#   'end': 3125168274356.467,
#   'forward_memory': [Memory(other|1022041984|free): Bytes:88752, Start:3125168274323.694, End:3125168281702.679, Comments: ],
# ...

# %%
layers = first_iter.layer_summary()
for layer in layers:
    bk = layer.get("backward_memory")
    for mem in bk:
        print(mem.free_time)
# Out:
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# 3125169046034.059
# None
# ...
