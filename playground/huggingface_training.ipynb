# %%
from perf_estimator.dataset import image_dataset

# %%
image_ds = image_dataset(batch=50, image_size=(86, 86))

# %%
first_iteration = next(iter(image_ds))

# %%
import torch

# %%
dev = torch.device('cuda:0')

# %%
not "cude" in str(dev)
# Out:
# True
