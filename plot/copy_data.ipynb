# %%
import shutil
import tqdm
from pathlib import Path
from ures.files import filter_files

# %%
data_dir = Path("/Volumes/ResearchData/101-xMem-LLM/005-LLM Experiments/005-new experiments")

# %%
result_files = filter_files("evaluation_result.json", data_dir, fuzz=False)
len(result_files)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result_files = filter_files("evaluation_result.json", data_dir, fuzz=False)
#       2 len(result_files)
#
# File /opt/anaconda3/envs/Huggingface/lib/python3.12/site-packages/ures/files.py:57, in filter_files(part_file_name, directory, fuzz)
#      35 """
#      36 Retrieve file paths in the specified directory that match a given file name pattern.
#      37
#    (...)
#      54     ['/tmp/test/example.txt']
#      55 """
#      56 # Note: Using get_file_paths instead of a non-existent fetch_file_paths.
# ---> 57 file_paths = get_file_paths(directory)
#      58 if fuzz:
#      59     return [
#      60         str(file_path)
#      61         for file_path in file_paths
#      62         if part_file_name in os.path.basename(str(file_path))
#      63     ]
#
# File /opt/anaconda3/envs/Huggingface/lib/python3.12/site-packages/ures/files.py:26, in get_file_paths(directory)
#      24 file_paths = []
#      25 # Walk through the directory and its subdirectories.
# ---> 26 for root, _, files in os.walk(directory):
#      27     for file in files:
#      28         # Join the root path with the file name to get the absolute path.
#      29         file_path = os.path.join(root, file)
#
# File <frozen os>:377, in walk(top, topdown, onerror, followlinks)
#
# KeyboardInterrupt:

# %%
current_dir = Path().resolve()
target_data_dir = current_dir.joinpath("data_new")
target_data_dir.mkdir(parents=True, exist_ok=True)

# %%
for src_file in tqdm.tqdm(result_files):
    partial_path = src_file.split(str(data_dir))[-1][1:]
    new_target_file = target_data_dir.joinpath(partial_path)
    new_target_file.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(src_file, new_target_file)
# Out:
# 0it [00:00, ?it/s]
