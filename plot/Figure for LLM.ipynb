# %%
from pathlib import Path
from plot.plot import ExperimentPlot
from IPython.display import Markdown, display

# %%
project_base = Path().home().joinpath("Transformer-Exp")
project_base = Path().home().joinpath("CNN-Exp")
project_base = Path().home().joinpath("Documents/301-ResearchData/101-xMem-LLM/005-LLM Experiments/005-new experiments/Transformer-Exp-20250423-3-4060")

# %%
e_plot = ExperimentPlot(output_dir=project_base)

# %%
fig = e_plot.llm_plot_relative_error_in_box_diagram_with_verification_data(
    title="Evaluation-Relative Error Experiments Result across Estimators-SGD",
    data_dir=project_base,
    overall_median=False,
    image_size=(1000, 400),
    font_size=20,
    legend_font_size=18,
    tickfont_size=22,
    view_mode = False,
    yrange=(0, 100),
)
fig.show()
# Out:
# <div>                            <div id="f77c9ff8-96d4-43e3-aa9c-f84b598912cc" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f77c9ff8-96d4-43e3-aa9c-f84b598912cc")) {                    Plotly.newPlot(                        "f77c9ff8-96d4-43e3-aa9c-f84b598912cc",                        [{"alignmentgroup":"True","hovertemplate":"Estimator=SchedTune\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","size":3},"name":"SchedTune","notched":false,"offsetgroup":"SchedTune","orientation":"v","showlegend":true,"x":["T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","T5-small","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","t5-base","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","openai-community\u002fgpt2","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-350m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","facebook\u002fopt-125m","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M"],"x0":" ","xaxis":"x","y":[64.6279781068899,64.6279781068899,64.6279781068899,64.6279781068899,64.6279781068899,50.10649409627611,50.10649409627611,50.10649409627611,50.10649409627611,50.10649409627611,16.578967350037967,16.578967350037967, ...

# %%
fig = e_plot.llm_plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title="Evaluation-Comparison of Success Rate vs Relative Error-SGD",
    data_dir=project_base,
    image_size=(800, 800),
    title_font_size=35,
    legend_font_size=30,
    tickfont_size=25,
    quadrant_font_size=40,
    marker_size=16,
    view_mode=True
)
fig.show()
# Out:
# <div>                            <div id="f45d65b1-8cd7-478b-b1d8-08d33aaaab59" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f45d65b1-8cd7-478b-b1d8-08d33aaaab59")) {                    Plotly.newPlot(                        "f45d65b1-8cd7-478b-b1d8-08d33aaaab59",                        [{"customdata":[[15,0],[5,10],[15,0],[15,0],[10,5],[0,15],[15,0],[0,15]],"hovertemplate":"tool=DNNmem\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DNNmem","marker":{"color":"#FFA15A","symbol":"circle","size":12},"mode":"markers","name":"DNNmem","orientation":"v","showlegend":true,"x":[100.0,33.33333333333333,100.0,100.0,66.66666666666666,0.0,100.0,0.0],"xaxis":"x","y":[19.57,11.9,20.21,30.77,14.51,6.17,18.92,3.32],"yaxis":"y","type":"scatter"},{"customdata":[[5,10],[15,0],[15,0],[15,0],[10,5],[5,10],[15,0],[5,10]],"hovertemplate":"tool=LLmem\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LLmem","marker":{"color":"#19d3f3","symbol":"diamond","size":12},"mode":"markers","name":"LLmem","orientation":"v","showlegend":true,"x":[33.33333333333333,100.0,100.0,100.0,66.66666666666666,33.33333333333333,100.0,33.33333333333333],"xaxis":"x","y":[42.26,100.0,65.52,66.19,71.52,55.4,69.83,100.0],"yaxis":"y","type":"scatter"},{"customdata":[[15,0],[15,0],[10,5],[15,0],[14,1],[15,0],[15,0],[15,0]],"hovertemplate":"tool=SchedTune\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","symbol":"square","size":12},"mode":"markers","name":"SchedTune","orientation":"v","showlegend":true,"x":[100.0,100.0,66.66666666666666,100.0,93.33333333333333,100.0,100.0,100.0],"xaxis":"x","y":[50.13,50.11,36.3,54.86,31.69,51.11,49.27,51.75],"yaxis":"y","type":"scatter"},{"customdata":[[5,10],[0,15],[0,15],[1,14],[1,14],[5,10],[2,13],[5,10]],"hovertemplate":"tool=xMem (this paper)\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"xMem (this paper)","marker":{"color":"#377eb8","symbol":"x","size":12},"mode":"markers","name":"xMem (this paper)","orientation":"v","showlegend":true,"x":[33.33333333333333,0.0,0.0,6.666666666666667,6.666666666666667,33.33333333333333,13.333333333333334,33.33333333333333],"xaxis":"x","y":[3.42,1.71,1.64,7.74,5.16,3.43,2.67,3.34],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropl ...

# %%
e_plot.data_processing(project_base)
# Out:
#                           model  batch_size  target_iteration optimiser  \
# 0    cerebras/Cerebras-GPT-111M          10                 3     AdamW
# 1    cerebras/Cerebras-GPT-111M          10                 3     AdamW
# 2    cerebras/Cerebras-GPT-111M          10                 3     AdamW
# 3    cerebras/Cerebras-GPT-111M          10                 3     AdamW
# 4    cerebras/Cerebras-GPT-111M          10                 3     AdamW
# ..                          ...         ...               ...       ...
# 370                    T5-small          30                 3     AdamW
# 371                    T5-small          30                 3     AdamW
# 372                    T5-small          30                 3     AdamW
# 373                    T5-small          30                 3     AdamW
# 374                    T5-small          30                 3     AdamW
#
#      device   input_size zero_grad_mode  total_gpu_memory used_gpu_memory  \
# 0         1  [86, 86, 3]           None       12622168064            None
# 1         1  [86, 86, 3]           None       12622168064            None
# 2         1  [86, 86, 3]           None       12622168064            None
# 3         1  [86, 86, 3]           None       12622168064            None
# 4         1  [86, 86, 3]           None       12622168064            None
# ..      ...          ...            ...               ...             ...
# 370       1  [86, 86, 3]           None       12622168064            None
# 371       1  [86, 86, 3]           None       12622168064            None
# 372       1  [86, 86, 3]           None       12622168064            None
# 373       1  [86, 86, 3]           None       12622168064            None
# 374       1  [86, 86, 3]           None       12622168064            None
#
#                     gpu_name  ... accurate_estimation   save_memory  \
# 0    NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 1    NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 2    NVIDIA GeForce RTX 3060  ...               False  0.000000e+00
# 3    NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 4    NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# ..                       ...  ...                 ...           ...
# 370  NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 371  NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 372  NVIDIA GeForce RTX 3060  ...               False  0.000000e+00
# 373  NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
# 374  NVIDIA GeForce RTX 3060  ...                True  1.262217e+10
#
#            memory    oom      runtime      ground     error  real_oom  \
# 0    3.855037e+09  False     33529788  3575644160  0.078138     False
# 1    3.749708e+09  False   7255985009  3575644160  0.048680     False
# 2    1.883242e+09  False    984134398  3575644160  0.473314     False
# 3    3.855037e+09  False     34162525  3575644160  0.078138     False
# 4    3.749708e+09  False   6577968316  3575644160  0.048680     False
# ..            ...    ...          ...         ...       ...       ...
# 370  6.417285e+09  False  37822999131  6517948416  0.015444     False
# 371  8.638169e+09  False   2778108662  6517948416  0.325290     False
# 372  2.544139e+09  False     37034665  6517948416  0.609672     False
# 373  6.417285e+09  False  37534916581  6517948416  0.015444     False
# 374  8.638169e+09  False   2746509580  6517948416  0.325290     False
#
#      correct_estimation    color
# 0                  True  #4daf4a
# 1                  True  #377eb8
# 2                  True   DNNmem
# 3                  True  #4daf4a
# 4                  True  #377eb8
# ..                  ...      ...
# 370                True  #377eb8
# 371                True   DNNmem
# 372                True  #4daf4a
# 373                True  #377eb8
# 374                True   DNNmem
#
# [375 rows x 24 columns]
