# %%
from pathlib import Path
from plot.plot import ExperimentPlot
from IPython.display import Markdown, display

# %%
project_base = Path().home().joinpath("DL-Estimator")
project_base = Path("/home/glaswegian/Documents/301-ResearchData/101-xMem-LLM/005-LLM Experiments/001-1st experiments")

# %%
e_plot = ExperimentPlot(output_dir=project_base)

# %%
fig = e_plot.llm_plot_relative_error_in_box_diagram_with_verification_data(
    title="Evaluation-Relative Error Experiments Result across Estimators-SGD",
    data_dir=project_base,
    overall_median=False,
    image_size=(2000, 400),
    font_size=20,
    legend_font_size=18,
    tickfont_size=22,
    view_mode = True,
    yrange=(0, 20),
)
fig.show()
# Out:
# <div>                            <div id="3a41dd7a-eaab-42a4-a3b3-5f73bc20c646" class="plotly-graph-div" style="height:350px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a41dd7a-eaab-42a4-a3b3-5f73bc20c646")) {                    Plotly.newPlot(                        "3a41dd7a-eaab-42a4-a3b3-5f73bc20c646",                        [{"alignmentgroup":"True","hovertemplate":"Model=EleutherAI\u002fgpt-neo-125M\u003cbr\u003eEstimator=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EleutherAI\u002fgpt-neo-125M","marker":{"color":"#FFA15A","size":3},"name":"EleutherAI\u002fgpt-neo-125M","notched":false,"offsetgroup":"EleutherAI\u002fgpt-neo-125M","orientation":"v","showlegend":true,"x":["xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem"],"x0":" ","xaxis":"x","y":[0.4984423676012461,0.4984423676012461,9.977452085682074,3.0358227079538556,16.80522565320665,5.023474178403756,5.378858746492049,13.138686131386862,5.023474178403756,15.071368597816962,0.35765379113018597,17.736734095573144,5.61516452074392,0.35765379113018597,5.77568838146407,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,6.5428333795397835,5.300649486695998,5.300649486695998,5.300649486695998,5.300649486695998,5.300649486695998,4.907183212267958,4.907183212267958,4.907183212267958,4.907183212267958,4.907183212267958,4.9786075457020615,4.9786075457020615,4.9786075457020615,4.9786075457020615,4.9786075457020615,null,null,null,null,null],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model=T5-small\u003cbr\u003eEstimator=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T5-small","marker":{"color":"#19d3f3","size":3},"name":"T5-small","notched":false,"offsetgroup":"T5-small","orientation":"v","showlegend":true,"x":["xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem","xMem"],"x0":" ","xaxis":"x","y":[4.61361014994233,13.038906414300735,13.938753959873285,4.61361014994233,4.61361014994233,5.2356020942408374,5.833956619296933,5.2356020942408374,5.2356020942408374,5.2356020942408374,5.064715813168261,5.064715813168261,5.064715813168261,5.118110236220472,5.064715813168261,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.86048604860486,4.830454254638516,4.830454254638516,4.830454254638516,4.830454254638516,4.830454254638516,4.713541666666667,4.713541666666667,4.713541666666667,4.713541666666667,4.713541666666667,5.367752509731613,5.367752509731613,5.367752509731613,5.367752509731613,5.367752509731613,4.754385964912281,4.754385964912281,4.754385964912281,4.754385964912281,4.754385964912281],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Model=cerebras\u002fCerebras-GPT-111M\u003cbr\u003eEstimator=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cerebras\u002fCerebras-GPT-111M","marker":{"color":"#FF6692","size":3},"name":"cerebras\u002fCerebras-GPT-111M","notched":false,"offsetgroup":"cerebras\u002fCerebras-GPT-111M","orientation":"v","showlegend":true,"x":["xMem","xMem","xMem","xMem"," ...

# %%
fig = e_plot.llm_plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title="Evaluation-Comparison of Success Rate vs Relative Error-SGD",
    data_dir=project_base,
    image_size=(800, 800),
    title_font_size=35,
    legend_font_size=30,
    tickfont_size=25,
    quadrant_font_size=40,
    marker_size=16,
    view_mode=True
)
fig.show()
# Out:
# <div>                            <div id="c224542d-19f9-4bea-bf0e-7e8a58be9707" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c224542d-19f9-4bea-bf0e-7e8a58be9707")) {                    Plotly.newPlot(                        "c224542d-19f9-4bea-bf0e-7e8a58be9707",                        [{"customdata":[[15,20]],"hovertemplate":"model=EleutherAI\u002fgpt-neo-125M\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EleutherAI\u002fgpt-neo-125M","marker":{"color":"#FFA15A","symbol":"circle","size":12},"mode":"markers","name":"EleutherAI\u002fgpt-neo-125M","orientation":"v","showlegend":true,"x":[42.857142857142854],"xaxis":"x","y":[4.88],"yaxis":"y","type":"scatter"},{"customdata":[[10,25]],"hovertemplate":"model=T5-small\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T5-small","marker":{"color":"#19d3f3","symbol":"diamond","size":12},"mode":"markers","name":"T5-small","orientation":"v","showlegend":true,"x":[28.57142857142857],"xaxis":"x","y":[5.41],"yaxis":"y","type":"scatter"},{"customdata":[[0,35]],"hovertemplate":"model=cerebras\u002fCerebras-GPT-111M\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cerebras\u002fCerebras-GPT-111M","marker":{"color":"#FF6692","symbol":"square","size":12},"mode":"markers","name":"cerebras\u002fCerebras-GPT-111M","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[0.98],"yaxis":"y","type":"scatter"},{"customdata":[[1,34]],"hovertemplate":"model=distilbert\u002fdistilgpt2\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"distilbert\u002fdistilgpt2","marker":{"color":"#B6E880","symbol":"x","size":12},"mode":"markers","name":"distilbert\u002fdistilgpt2","orientation":"v","showlegend":true,"x":[2.857142857142857],"xaxis":"x","y":[6.22],"yaxis":"y","type":"scatter"},{"customdata":[[16,19]],"hovertemplate":"model=facebook\u002fopt-125m\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"facebook\u002fopt-125m","marker":{"color":"#FF97FF","symbol":"cross","size":12},"mode":"markers","name":"facebook\u002fopt-125m","orientation":"v","showlegend":true,"x":[45.714285714285715],"xaxis":"x","y":[3.4],"yaxis":"y","type":"scatter"},{"customdata":[[0,33]],"hovertemplate":"model=openai-community\u002fgpt2\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"openai-community\u002fgpt2","marker":{"color":"#FECB52","symbol":"circle","size":12},"mode":"markers","name":"openai-community\u002fgpt2","orientation":"v","showlegend":true,"x":[0.0],"xaxis":"x","y":[0.56],"yaxis":"y","type":"scatte ...

# %%
e_plot.data_processing(project_base)
# Out:
#                           model  batch_size  target_iteration optimiser  \
# 0    cerebras/Cerebras-GPT-111M           5                 2     AdamW
# 1    cerebras/Cerebras-GPT-111M           5                 2     AdamW
# 2    cerebras/Cerebras-GPT-111M           5                 2     AdamW
# 3    cerebras/Cerebras-GPT-111M           5                 2     AdamW
# 4    cerebras/Cerebras-GPT-111M           5                 2     AdamW
# ..                          ...         ...               ...       ...
# 203                    T5-small          65                 2     AdamW
# 204                    T5-small          65                 2     AdamW
# 205                    T5-small          65                 2     AdamW
# 206                    T5-small          65                 2     AdamW
# 207                    T5-small          65                 2     AdamW
#
#      device input_size zero_grad_mode  total_gpu_memory used_gpu_memory  \
# 0         0     [0, 0]           None          15.47937            None
# 1         0     [0, 0]           None          15.47937            None
# 2         0     [0, 0]           None          15.47937            None
# 3         0     [0, 0]           None          15.47937            None
# 4         0     [0, 0]           None          15.47937            None
# ..      ...        ...            ...               ...             ...
# 203       0     [0, 0]           None          15.47937            None
# 204       0     [0, 0]           None          15.47937            None
# 205       0     [0, 0]           None          15.47937            None
# 206       0     [0, 0]           None          15.47937            None
# 207       0     [0, 0]           None          15.47937            None
#
#                   timestamp  ... accurate_estimation save_memory  \
# 0         cerebras-Cerebras  ...                True   12.719604
# 1         cerebras-Cerebras  ...                True   13.059448
# 2         cerebras-Cerebras  ...                True   12.721558
# 3         cerebras-Cerebras  ...                True   12.719604
# 4         cerebras-Cerebras  ...                True   12.719604
# ..                      ...  ...                 ...         ...
# 203  T5-small_AdamW_65_4373  ...               False    0.000000
# 204  T5-small_AdamW_65_cce6  ...               False    0.000000
# 205  T5-small_AdamW_65_d739  ...               False    0.000000
# 206  T5-small_AdamW_65_deeb  ...               False    0.000000
# 207  T5-small_AdamW_65_ff98  ...               False    0.000000
#
#            ground    framework       memory    oom  real_oom     error  \
# 0    3.074425e+09  365953024.0   2963275776  False     False  0.036153
# 1    3.202351e+09  365953024.0   2598371328  False     False  0.188605
# 2    3.072328e+09  365953024.0   2961178624  False     False  0.036177
# 3    3.072328e+09  365953024.0   2963275776  False     False  0.035495
# 4    3.074425e+09  365953024.0   2963275776  False     False  0.036153
# ..            ...          ...          ...    ...       ...       ...
# 203  1.316592e+10  365953024.0  12442402816  False     False  0.054954
# 204  1.316592e+10  365953024.0  12442402816  False     False  0.054954
# 205  1.316592e+10  365953024.0  12442402816  False     False  0.054954
# 206  1.316592e+10  365953024.0  12442402816  False     False  0.054954
# 207  1.316592e+10  365953024.0  12442402816  False     False  0.054954
#
#      correct_estimation  color
# 0                  True   xMem
# 1                  True   xMem
# 2                  True   xMem
# 3                  True   xMem
# 4                  True   xMem
# ..                  ...    ...
# 203                True   xMem
# 204                True   xMem
# 205                True   xMem
# 206                True   xMem
# 207                True   xMem
#
# [208 rows x 23 columns]
