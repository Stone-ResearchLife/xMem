# %%
from pathlib import Path
from plot.plot import ExperimentPlot
from IPython.display import Markdown, display

# %%
project_base = Path().home().joinpath("Transformer-Exp")
# project_base = Path().home().joinpath("CNN-Exp")

# %%
e_plot = ExperimentPlot(output_dir=project_base)

# %%
fig = e_plot.llm_plot_relative_error_in_box_diagram_with_verification_data(
    title="Evaluation-Relative Error Experiments Result across Estimators-SGD",
    data_dir=project_base,
    overall_median=False,
    image_size=(500, 400),
    font_size=20,
    legend_font_size=18,
    tickfont_size=22,
    view_mode = True,
    yrange=(0, 200),
)
fig.show()
# Out:
# <div>                            <div id="d45bc078-d84e-4b7e-a7d4-bb35f9e8f02f" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d45bc078-d84e-4b7e-a7d4-bb35f9e8f02f")) {                    Plotly.newPlot(                        "d45bc078-d84e-4b7e-a7d4-bb35f9e8f02f",                        [{"alignmentgroup":"True","hovertemplate":"Estimator=DNNmem\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DNNmem","marker":{"color":"#FFA15A","size":3},"name":"DNNmem","notched":false,"offsetgroup":"DNNmem","orientation":"v","showlegend":true,"x":["EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M"],"x0":" ","xaxis":"x","y":[12.465034965034965,21.675421620127178,29.303857008466604,18.957940991839298,2.6976267713846678],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Estimator=SchedTune\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","size":3},"name":"SchedTune","notched":false,"offsetgroup":"SchedTune","orientation":"v","showlegend":true,"x":["EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M"],"x0":" ","xaxis":"x","y":[68.64047202797202,50.407381808128285,15.62723424270931,62.46568319732161,69.3739969267543],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Estimator=Solution\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solution","marker":{"color":"#19d3f3","size":3},"name":"Solution","notched":false,"offsetgroup":"Solution","orientation":"v","showlegend":true,"x":["EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M"],"x0":" ","xaxis":"x","y":[3.688811188811189,5.612385955211501,3.9981185324553152,4.687173048754969,25.900631722724942],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinew ...

# %%
fig = e_plot.llm_plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title="Evaluation-Comparison of Success Rate vs Relative Error-SGD",
    data_dir=project_base,
    image_size=(800, 800),
    title_font_size=35,
    legend_font_size=30,
    tickfont_size=25,
    quadrant_font_size=40,
    marker_size=16,
    view_mode=True
)
fig.show()
# Out:
# <div>                            <div id="d075fd80-fd3a-4996-b3af-391c81ea11f1" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d075fd80-fd3a-4996-b3af-391c81ea11f1")) {                    Plotly.newPlot(                        "d075fd80-fd3a-4996-b3af-391c81ea11f1",                        [{"customdata":[[5,0],[5,0],[5,0]],"hovertemplate":"model=EleutherAI\u002fgpt-neo-125M\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EleutherAI\u002fgpt-neo-125M","marker":{"color":"#FFA15A","symbol":"circle","size":12},"mode":"markers","name":"EleutherAI\u002fgpt-neo-125M","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[18.96,62.47,4.69],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tic ...

# %%
e_plot.data_processing(project_base)
# Out:
#                       model  batch_size  target_iteration optimiser  device  \
# 0   EleutherAI/gpt-neo-125M          40                 3     AdamW       1
# 1   EleutherAI/gpt-neo-125M          40                 3     AdamW       1
# 2   EleutherAI/gpt-neo-125M          40                 3     AdamW       1
# 3   EleutherAI/gpt-neo-125M          20                 3     AdamW       1
# 4   EleutherAI/gpt-neo-125M          20                 3     AdamW       1
# 5   EleutherAI/gpt-neo-125M          20                 3     AdamW       1
# 6   EleutherAI/gpt-neo-125M          10                 3     AdamW       1
# 7   EleutherAI/gpt-neo-125M          10                 3     AdamW       1
# 8   EleutherAI/gpt-neo-125M          10                 3     AdamW       1
# 9   EleutherAI/gpt-neo-125M          30                 3     AdamW       1
# 10  EleutherAI/gpt-neo-125M          30                 3     AdamW       1
# 11  EleutherAI/gpt-neo-125M          30                 3     AdamW       1
# 12  EleutherAI/gpt-neo-125M          50                 3     AdamW       1
# 13  EleutherAI/gpt-neo-125M          50                 3     AdamW       1
# 14  EleutherAI/gpt-neo-125M          50                 3     AdamW       1
#
#      input_size zero_grad_mode  total_gpu_memory used_gpu_memory  \
# 0   [86, 86, 3]           None       12622168064            None
# 1   [86, 86, 3]           None       12622168064            None
# 2   [86, 86, 3]           None       12622168064            None
# 3   [86, 86, 3]           None       12622168064            None
# 4   [86, 86, 3]           None       12622168064            None
# 5   [86, 86, 3]           None       12622168064            None
# 6   [86, 86, 3]           None       12622168064            None
# 7   [86, 86, 3]           None       12622168064            None
# 8   [86, 86, 3]           None       12622168064            None
# 9   [86, 86, 3]           None       12622168064            None
# 10  [86, 86, 3]           None       12622168064            None
# 11  [86, 86, 3]           None       12622168064            None
# 12  [86, 86, 3]           None       12622168064            None
# 13  [86, 86, 3]           None       12622168064            None
# 14  [86, 86, 3]           None       12622168064            None
#
#                    gpu_name  ... accurate_estimation save_memory  \
# 0   NVIDIA GeForce RTX 3060  ...               False           0
# 1   NVIDIA GeForce RTX 3060  ...               False           0
# 2   NVIDIA GeForce RTX 3060  ...               False           0
# 3   NVIDIA GeForce RTX 3060  ...               False           0
# 4   NVIDIA GeForce RTX 3060  ...               False           0
# 5   NVIDIA GeForce RTX 3060  ...               False           0
# 6   NVIDIA GeForce RTX 3060  ...               False           0
# 7   NVIDIA GeForce RTX 3060  ...               False           0
# 8   NVIDIA GeForce RTX 3060  ...               False           0
# 9   NVIDIA GeForce RTX 3060  ...               False           0
# 10  NVIDIA GeForce RTX 3060  ...               False           0
# 11  NVIDIA GeForce RTX 3060  ...               False           0
# 12  NVIDIA GeForce RTX 3060  ...               False           0
# 13  NVIDIA GeForce RTX 3060  ...               False           0
# 14  NVIDIA GeForce RTX 3060  ...               False           0
#
#           memory    oom       runtime       ground     error  real_oom  \
# 0   1.050044e+10  False  5.637343e+09  11995709440  0.124650      True
# 1   3.761798e+09  False  3.639155e+07  11995709440  0.686405      True
# 2   1.243821e+10  False  2.504000e+01  11995709440  0.036888      True
# 3   5.941232e+09  False  2.796780e+09   7585398784  0.216754     False
# 4   3.761798e+09  False  3.531046e+07   7585398784  0.504074     False
# 5   7.159677e+09  False  2.319000e+01   7585398784  0.056124     False
# 6   3.152019e+09  False  1.695402e+09   4458545152  0.293039     False
# 7   3.761798e+09  False  3.535796e+07   4458545152  0.156272     False
# 8   4.280287e+09  False  2.191000e+01   4458545152  0.039981     False
# 9   8.122270e+09  False  4.778421e+09  10022289408  0.189579     False
# 10  3.761798e+09  False  3.998903e+07  10022289408  0.624657     False
# 11  9.552527e+09  False  2.437000e+01  10022289408  0.046872     False
# 12  1.261437e+10  False  1.043458e+10  12283019264  0.026976      True
# 13  3.761798e+09  False  3.726563e+07  12283019264  0.693740      True
# 14  1.546440e+10  False  2.625000e+01  12283019264  0.259006      True
#
#     correct_estimation     color
# 0                False    DNNmem
# 1                False   #4daf4a
# 2                False  Solution
# 3                 True    DNNmem
# 4                 True   #4daf4a
# 5                 True  Solution
# 6                 True    DNNmem
# 7                 True   #4daf4a
# 8                 True  Solution
# 9                 True    DNNmem
# 10                True   #4daf4a
# 11                True  Solution
# 12               False    DNNmem
# 13               False   #4daf4a
# 14               False  Solution
#
# [15 rows x 24 columns]
