# %%
from pathlib import Path
from plot.plot import ExperimentPlot
from IPython.display import Markdown, display

# %%
project_base = Path().home().joinpath("Transformer-Exp")
# project_base = Path().home().joinpath("CNN-Exp")

# %%
e_plot = ExperimentPlot(output_dir=project_base)

# %%
fig = e_plot.llm_plot_relative_error_in_box_diagram_with_verification_data(
    title="Evaluation-Relative Error Experiments Result across Estimators-SGD",
    data_dir=project_base,
    overall_median=False,
    image_size=(2000, 400),
    font_size=20,
    legend_font_size=18,
    tickfont_size=22,
    view_mode = True,
    yrange=(0, 100),
)
fig.show()
# Out:
# <div>                            <div id="82950f44-6884-4fe7-b953-f94e1c78d847" class="plotly-graph-div" style="height:350px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82950f44-6884-4fe7-b953-f94e1c78d847")) {                    Plotly.newPlot(                        "82950f44-6884-4fe7-b953-f94e1c78d847",                        [{"alignmentgroup":"True","hovertemplate":"Estimator=DNNmem\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DNNmem","marker":{"color":"#FFA15A","size":3},"name":"DNNmem","notched":false,"offsetgroup":"DNNmem","orientation":"v","showlegend":true,"x":["facebook\u002fopt-125m","distilbert\u002fdistilgpt2","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-125m","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","openai-community\u002fgpt2","EleutherAI\u002fgpt-neo-125M","openai-community\u002fgpt2","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","facebook\u002fopt-125m","T5-small","EleutherAI\u002fgpt-neo-125M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-125m","facebook\u002fopt-350m","distilbert\u002fdistilgpt2","EleutherAI\u002fgpt-neo-125M","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-125m","openai-community\u002fgpt2","openai-community\u002fgpt2","EleutherAI\u002fgpt-neo-125M","facebook\u002fopt-350m","T5-small","T5-small","facebook\u002fopt-125m","openai-community\u002fgpt2","T5-small","t5-base","distilbert\u002fdistilgpt2","cerebras\u002fCerebras-GPT-111M","distilbert\u002fdistilgpt2","openai-community\u002fgpt2"],"x0":" ","xaxis":"x","y":[13.389765294343977,15.897032815877383,40.40959040959041,24.15674603174603,23.959827833572454,15.789473684210526,12.259472326919262,6.467446224916991,8.72043317184383,18.22212837837838,18.691133484897694,18.862716231137284,26.585408938350113,20.64425770308123,16.399058017555127,15.28127623845508,16.21854532919683,18.781575037147103,6.8856767411300925,16.234516928158545,11.886231781519738,16.695677400638235,18.35385316917465,2.140716426430712,24.077407740774078,30.027932960893857,36.53519932145886,10.022883295194509,2.1604938271604937,18.55350782096949,6.070026178010472,31.175137584978955,35.48904329235703,27.647476901208247,22.30190032269631,20.713989207139893,4.8028578989150565],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Estimator=SchedTune\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","size":3},"name":"SchedTune","notched":false,"offsetgroup":"SchedTune","orientation":"v","showlegend":true,"x":["facebook\u002fopt-125m","distilbert\u002fdistilgpt2","facebook\u002fopt-350m","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-125m","distilbert\u002fdistilgpt2","distilbert\u002fdistilgpt2","openai-community\u002fgpt2","EleutherAI\u002fgpt-neo-125M","openai-community\u002fgpt2","EleutherAI\u002fgpt-neo-125M","EleutherAI\u002fgpt-neo-125M","facebook\u002fopt-125m","facebook\u002fopt-350m","T5-small","EleutherAI\u002fgpt-neo-125M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","cerebras\u002fCerebras-GPT-111M","t5-base","facebook\u002fopt-125m","facebook\u002fopt-350m","distilbert\u002fdistilgpt2","EleutherAI\u002fgpt-neo-125M","t5-base","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-125m","openai-community\u002fgpt2","facebook\u002fopt-350m","openai-community\u002fgpt2","t5-base","EleutherAI\u002fgpt-neo-125M","facebook\u002fopt-350m","T5-small","T5-small","facebook\u002fopt-125m","openai-community\u002fgpt2","T5-small","t5-base","t5-base","distilbert\u002fdistilgpt2","cerebras\u002fCerebras-GPT-111M","facebook\u002fopt-350m","distilbert\u002fdistilgpt2", ...

# %%
fig = e_plot.llm_plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title="Evaluation-Comparison of Success Rate vs Relative Error-SGD",
    data_dir=project_base,
    image_size=(800, 800),
    title_font_size=35,
    legend_font_size=30,
    tickfont_size=25,
    quadrant_font_size=40,
    marker_size=16,
    view_mode=True
)
fig.show()
# Out:
# <div>                            <div id="a97f5c3a-f536-4958-b7d1-a3f5d3002eef" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a97f5c3a-f536-4958-b7d1-a3f5d3002eef")) {                    Plotly.newPlot(                        "a97f5c3a-f536-4958-b7d1-a3f5d3002eef",                        [{"customdata":[[6,0],[6,0],[4,0]],"hovertemplate":"model=EleutherAI\u002fgpt-neo-125M\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EleutherAI\u002fgpt-neo-125M","marker":{"color":"#FFA15A","symbol":"circle","size":12},"mode":"markers","name":"EleutherAI\u002fgpt-neo-125M","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[18.46,63.06,4.42],"yaxis":"y","type":"scatter"},{"customdata":[[4,0],[4,0],[6,0]],"hovertemplate":"model=T5-small\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"T5-small","marker":{"color":"#19d3f3","symbol":"diamond","size":12},"mode":"markers","name":"T5-small","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[18.3,49.19,3.74],"yaxis":"y","type":"scatter"},{"customdata":[[6,0],[6,0],[4,0]],"hovertemplate":"model=cerebras\u002fCerebras-GPT-111M\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cerebras\u002fCerebras-GPT-111M","marker":{"color":"#FF6692","symbol":"square","size":12},"mode":"markers","name":"cerebras\u002fCerebras-GPT-111M","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[16.55,51.16,1.02],"yaxis":"y","type":"scatter"},{"customdata":[[6,0],[6,0],[5,0]],"hovertemplate":"model=distilbert\u002fdistilgpt2\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"distilbert\u002fdistilgpt2","marker":{"color":"#B6E880","symbol":"x","size":12},"mode":"markers","name":"distilbert\u002fdistilgpt2","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[18.47,65.42,7.22],"yaxis":"y","type":"scatter"},{"customdata":[[6,0],[6,0],[2,0]],"hovertemplate":"model=facebook\u002fopt-125m\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"facebook\u002fopt-125m","marker":{"color":"#FF97FF","symbol":"cross","size":12},"mode":"markers","name":"facebook\u002fopt-125m","orientation":"v","showlegend":true,"x":[100.0,100.0,100.0],"xaxis":"x","y":[18.67,48.07,2.48],"yaxis":"y","type":"scatter"},{"customdata":[[2,0],[6,0],[2,0]],"hovertemplate":"model=facebook\u002fopt-350m\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"facebook\u002fopt-350m","marker":{"color":"#FECB52","symbol":"circle","size":12},"mode":"markers","nam ...

# %%
e_plot.data_processing(project_base)
# Out:
#                       model  batch_size  target_iteration optimiser  device  \
# 0         facebook/opt-125m          20                 3     AdamW       0
# 1         facebook/opt-125m          20                 3     AdamW       0
# 2         facebook/opt-125m          20                 3     AdamW       0
# 3    microsoft/deberta-base          50                 3     AdamW       0
# 4     distilbert/distilgpt2          50                 3     AdamW       0
# ..                      ...         ...               ...       ...     ...
# 113  microsoft/deberta-base          30                 3     AdamW       0
# 114   openai-community/gpt2          60                 3     AdamW       0
# 115   openai-community/gpt2          60                 3     AdamW       0
# 116   openai-community/gpt2          60                 3     AdamW       0
# 117  microsoft/deberta-base          10                 3     AdamW       0
#
#       input_size zero_grad_mode  total_gpu_memory used_gpu_memory  \
# 0    [86, 86, 3]           None       16620847104            None
# 1    [86, 86, 3]           None       16620847104            None
# 2    [86, 86, 3]           None       16620847104            None
# 3    [86, 86, 3]           None       16620847104            None
# 4    [86, 86, 3]           None       16620847104            None
# ..           ...            ...               ...             ...
# 113  [86, 86, 3]           None       16620847104            None
# 114  [86, 86, 3]           None       16620847104            None
# 115  [86, 86, 3]           None       16620847104            None
# 116  [86, 86, 3]           None       16620847104            None
# 117  [86, 86, 3]           None       16620847104            None
#
#                     gpu_name  ... accurate_estimation save_memory  \
# 0    NVIDIA GeForce RTX 5080  ...               False           0
# 1    NVIDIA GeForce RTX 5080  ...               False           0
# 2    NVIDIA GeForce RTX 5080  ...               False           0
# 3    NVIDIA GeForce RTX 5080  ...               False           0
# 4    NVIDIA GeForce RTX 5080  ...               False           0
# ..                       ...  ...                 ...         ...
# 113  NVIDIA GeForce RTX 5080  ...               False           0
# 114  NVIDIA GeForce RTX 5080  ...               False           0
# 115  NVIDIA GeForce RTX 5080  ...               False           0
# 116  NVIDIA GeForce RTX 5080  ...               False           0
# 117  NVIDIA GeForce RTX 5080  ...               False           0
#
#            memory    oom       runtime       ground     error  real_oom  \
# 0    6.180307e+09  False  1.770469e+09   5450498048  0.133898     False
# 1    4.147464e+09  False  5.875626e+07   5450498048  0.239067     False
# 2    5.299503e+09  False  1.022000e+01   5450498048  0.027703     False
# 3    1.317850e+10  False  1.504300e+02  15411970048  0.144918      True
# 4    8.975811e+09  False  3.196928e+09  10672406528  0.158970     False
# ..            ...    ...           ...          ...       ...       ...
# 113  9.449767e+09  False  8.039000e+01  11142168576  0.151892     False
# 114  1.661154e+10  False  1.021443e+10  15850274816  0.048029      True
# 115  4.147464e+09  False  3.033010e+07  15850274816  0.738335      True
# 116  1.920362e+10  False  1.656000e+01  15850274816  0.211564      True
# 117  4.112515e+09  False  1.455300e+02   4750049280  0.134216     False
#
#      correct_estimation     color
# 0                  True    DNNmem
# 1                  True   #4daf4a
# 2                  True  Solution
# 3                 False  Solution
# 4                  True    DNNmem
# ..                  ...       ...
# 113                True  Solution
# 114               False    DNNmem
# 115               False   #4daf4a
# 116               False  Solution
# 117                True  Solution
#
# [118 rows x 24 columns]
