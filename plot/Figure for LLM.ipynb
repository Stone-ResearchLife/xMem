# %%
from pathlib import Path
from plot.plot import ExperimentPlot
import logging
from exp.run import ExperimentRun, SummarySectionName
from exp.config import TransformerExperiments, CNNExperiments

# %%
config = TransformerExperiments()
config = CNNExperiments()
exp = ExperimentRun(config=config)
exp.statistics()
# Out:
# 100%|██████████| 543/543 [00:00<00:00, 19073.48it/s]
# =============== Statistics for CNN-Exp ==================
# train: 543/543
# config: 543/543
# groundtruth: 529/543
# solution: 529/543
# schedtune: 530/543
# DNNmem: 530/543
# LLmem: 0/543

# %%
exp.to_evaluation_result()
# Out:
#   0%|          | 0/543 [00:00<?, ?it/s]Ground truth not found for RegNetY400MF_SGD_859_1_65e9/NVIDIA-GeForce-RTX-3060
# Ground truth not found for MobeNetV3Small_AdamW_414_0_3e13/NVIDIA-GeForce-RTX-4060
# Ground truth not found for MobeNetV3Small_Adam_405_1_17e6/NVIDIA-GeForce-RTX-3060
# Ground truth not found for ResNet152_AdamW_1000_1_8e11/NVIDIA-GeForce-RTX-3060
# Ground truth not found for MobileNetV2_SGD_457_0_7e97/NVIDIA-GeForce-RTX-4060
# Ground truth not found for MobeNetV3Small_RMSprop_385_1_44e4/NVIDIA-GeForce-RTX-3060
# Ground truth not found for ResNet101_SGD_557_0_4e11/NVIDIA-GeForce-RTX-4060
# Ground truth not found for VGG16_AdamW_836_1_79e9/NVIDIA-GeForce-RTX-3060
# Ground truth not found for VGG16_AdamW_710_0_7f06/NVIDIA-GeForce-RTX-4060
# Ground truth not found for ResNet152_SGD_556_0_3e80/NVIDIA-GeForce-RTX-4060
# Ground truth not found for MnasNet_RMSprop_628_0_40e1/NVIDIA-GeForce-RTX-4060
# Ground truth not found for VGG16_RMSprop_604_0_35e6/NVIDIA-GeForce-RTX-4060
# Ground truth not found for MnasNet_RMSprop_524_0_47e8/NVIDIA-GeForce-RTX-4060
# Ground truth not found for RegNetY400MF_Adam_566_0_33e3/NVIDIA-GeForce-RTX-4060
# 100%|██████████| 543/543 [00:00<00:00, 6746.87it/s]
# [{'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 5956202980,
#   'ground': 12362711040,
#   'error': 0.06261916878710777,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12664700928,
#   'oom': True,
#   'runtime': 29490559978,
#   'ground': 12362711040,
#   'error': 0.024427480916030534,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12670992384,
#   'oom': True,
#   'runtime': 158076793588,
#   'ground': 12362711040,
#   'error': 0.024936386768447838,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10756303093.76,
#   'oom': False,
#   'runtime': 4165248169,
#   'ground': 11756634112,
#   'error': 0.08508651444880483,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12425625600,
#   'oom': False,
#   'runtime': 11127471384,
#   'ground': 11756634112,
#   'error': 0.05690331787370674,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': False, 'error': 0.07563325008919015}},
#  {'tool': 'DNNmem',
#   'memory': 11330912256,
#   'oom': False,
#   'runtime': 39054484662,
#   'ground': 11756634112,
#   'error': 0.03621120228326793,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9270858874.88,
#   'oom': True,
#   'runtime': 1164582961,
#   'ground': 6283067392,
#   'error': 0.4755307076101467,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 6209667072,
#   'oom': False,
#   'runtime': 15523405664,
#   'ground': 6283067392,
#   'error': 0.011682242990654205,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.036715620827770364}},
#  {'tool': 'DNNmem',
#   'memory': 5788139520,
#   'oom': False,
#   'runtime': 18551948923,
#   'ground': 6283067392,
#   'error': 0.0787716955941255,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0016688918558077437}},
#  {'tool': 'SchedTune',
#   'memory': 4886458531.84,
#   'oom': False,
#   'runtime': 1634833582,
#   'ground': 8799649792,
#   'error': 0.44469852240228785,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8426356736,
#   'oom': False,
#   'runtime': 5052558515,
#   'ground': 8799649792,
#   'error': 0.04242135367016206,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.1275023832221163}},
#  {'tool': 'DNNmem',
#   'memory': 5702156288,
#   'oom': False,
#   'runtime': 26259328575,
#   'ground': 8799649792,
#   'error': 0.35200190657769304,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 4075468965,
#   'ground': 8032092160,
#   'error': 0.6313603133159268,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8386510848,
#   'oom': True,
#   'runtime': 25097920531,
#   'ground': 8032092160,
#   'error': 0.04412532637075718,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8424259584,
#   'oom': True,
#   'runtime': 146516402141,
#   'ground': 8032092160,
#   'error': 0.04882506527415144,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9115197767.68,
#   'oom': False,
#   'runtime': 964132098,
#   'ground': 5645533184,
#   'error': 0.6145858098068351,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.6038131500742943}},
#  {'tool': 'solution',
#   'memory': 5010096128,
#   'oom': False,
#   'runtime': 26967890739,
#   'ground': 5645533184,
#   'error': 0.11255572065378901,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.006315007429420505}},
#  {'tool': 'DNNmem',
#   'memory': 4997513216,
#   'oom': False,
#   'runtime': 43979067836,
#   'ground': 5645533184,
#   'error': 0.11478454680534918,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.005572065378900446}},
#  {'tool': 'SchedTune',
#   'memory': 4886458531.84,
#   'oom': False,
#   'runtime': 1584154818,
#   'ground': 7405043712,
#   'error': 0.3401175304446332,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 7553941504,
#   'oom': False,
#   'runtime': 4558736479,
#   'ground': 7405043712,
#   'error': 0.02010761823845936,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.19059756442934014}},
#  {'tool': 'DNNmem',
#   'memory': 5473566720,
#   'oom': False,
#   'runtime': 25960677261,
#   'ground': 7405043712,
#   'error': 0.2608326253186066,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.07448314924950439}},
#  {'tool': 'SchedTune',
#   'memory': 2940899164.16,
#   'oom': False,
#   'runtime': 443065983,
#   'ground': 1841299456,
#   'error': 0.5971867881548975,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.5015148063781321}},
#  {'tool': 'solution',
#   'memory': 1694498816,
#   'oom': False,
#   'runtime': 13169202383,
#   'ground': 1841299456,
#   'error': 0.07972665148063782,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.06492027334851937}},
#  {'tool': 'DNNmem',
#   'memory': 1746927616,
#   'oom': False,
#   'runtime': 40084565965,
#   'ground': 1841299456,
#   'error': 0.05125284738041002,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04100227790432802}},
#  {'tool': 'SchedTune',
#   'memory': 8972906004.48,
#   'oom': True,
#   'runtime': 3235229562,
#   'ground': 7602176000,
#   'error': 0.1803075862068965,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8810135552,
#   'oom': True,
#   'runtime': 9731666955,
#   'ground': 7602176000,
#   'error': 0.15889655172413794,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8426356736,
#   'oom': True,
#   'runtime': 31390550733,
#   'ground': 7602176000,
#   'error': 0.10841379310344827,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13129922641.92,
#   'oom': True,
#   'runtime': 2941941137,
#   'ground': 12218007552,
#   'error': 0.07463697219361484,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12708741120,
#   'oom': True,
#   'runtime': 30069164261,
#   'ground': 12218007552,
#   'error': 0.04016477857878476,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 11093934080,
#   'oom': False,
#   'runtime': 80584971879,
#   'ground': 12218007552,
#   'error': 0.09200137315482321,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10115853844.48,
#   'oom': True,
#   'runtime': 2621746096,
#   'ground': 8059355136,
#   'error': 0.2551691386937288,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8420065280,
#   'oom': True,
#   'runtime': 34380970123,
#   'ground': 8059355136,
#   'error': 0.044756700494405416,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8436842496,
#   'oom': True,
#   'runtime': 221319493770,
#   'ground': 8059355136,
#   'error': 0.0468384074941452,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 3026835751,
#   'ground': 8015314944,
#   'error': 0.634774986917844,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8415870976,
#   'oom': True,
#   'runtime': 22964530038,
#   'ground': 8015314944,
#   'error': 0.0499738356881214,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8392802304,
#   'oom': True,
#   'runtime': 140123434548,
#   'ground': 8015314944,
#   'error': 0.04709576138147567,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9852105523.2,
#   'oom': True,
#   'runtime': 1613348502,
#   'ground': 8059355136,
#   'error': 0.22244340359094467,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8472494080,
#   'oom': True,
#   'runtime': 17416886989,
#   'ground': 8059355136,
#   'error': 0.051262034868592245,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 7394557952,
#   'oom': False,
#   'runtime': 22029176018,
#   'ground': 8059355136,
#   'error': 0.08248763986468904,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 4231476019.2,
#   'oom': False,
#   'runtime': 559206998,
#   'ground': 3877634048,
#   'error': 0.09125202812330985,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.06745538128718222}},
#  {'tool': 'solution',
#   'memory': 3856662528,
#   'oom': False,
#   'runtime': 7788312022,
#   'ground': 3877634048,
#   'error': 0.005408328826392645,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.010275824770146024}},
#  {'tool': 'DNNmem',
#   'memory': 2847932416,
#   'oom': False,
#   'runtime': 12522827433,
#   'ground': 3877634048,
#   'error': 0.26554894537587886,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9328876584.96,
#   'oom': False,
#   'runtime': 1282379341,
#   'ground': 6660554752,
#   'error': 0.40061555415617117,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.37857525188916863}},
#  {'tool': 'solution',
#   'memory': 6727663616,
#   'oom': False,
#   'runtime': 17093691517,
#   'ground': 6660554752,
#   'error': 0.010075566750629723,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.06832493702770781}},
#  {'tool': 'DNNmem',
#   'memory': 6272581632,
#   'oom': False,
#   'runtime': 18816608886,
#   'ground': 6660554752,
#   'error': 0.058249370277078084,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.02644836272040302}},
#  {'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 7376871909,
#   'ground': 12358516736,
#   'error': 0.06297980655014429,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12761169920,
#   'oom': True,
#   'runtime': 43096015105,
#   'ground': 12358516736,
#   'error': 0.03258102833870694,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12656312320,
#   'oom': True,
#   'runtime': 318525676291,
#   'ground': 12358516736,
#   'error': 0.024096385542168676,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10733370736.64,
#   'oom': True,
#   'runtime': 1943254441,
#   'ground': 8065646592,
#   'error': 0.3307514300572022,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8451522560,
#   'oom': True,
#   'runtime': 20436597550,
#   'ground': 8065646592,
#   'error': 0.04784191367654706,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8115978240,
#   'oom': False,
#   'runtime': 27059640154,
#   'ground': 8065646592,
#   'error': 0.0062402496099844,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 4194851087,
#   'ground': 12306087936,
#   'error': 0.06750852079072943,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12731809792,
#   'oom': True,
#   'runtime': 25814602261,
#   'ground': 12306087936,
#   'error': 0.034594410361281525,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12675186688,
#   'oom': True,
#   'runtime': 150712477604,
#   'ground': 12306087936,
#   'error': 0.029993183367416496,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 5451368366.08,
#   'oom': False,
#   'runtime': 2024854637,
#   'ground': 9508487168,
#   'error': 0.42668394353771505,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 6977224704,
#   'oom': False,
#   'runtime': 5232377517,
#   'ground': 9508487168,
#   'error': 0.2662108513453904,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.08756065284516983}},
#  {'tool': 'DNNmem',
#   'memory': 5838471168,
#   'oom': False,
#   'runtime': 32888818765,
#   'ground': 9508487168,
#   'error': 0.38597265108072343,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05580061755624173}},
#  {'tool': 'SchedTune',
#   'memory': 7469940080.64,
#   'oom': False,
#   'runtime': 1479184701,
#   'ground': 7344226304,
#   'error': 0.017117361507709927,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.006551970302684227}},
#  {'tool': 'solution',
#   'memory': 7589593088,
#   'oom': False,
#   'runtime': 23182309813,
#   'ground': 7344226304,
#   'error': 0.03340948029697316,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.034551684751570534}},
#  {'tool': 'DNNmem',
#   'memory': 7113539584,
#   'oom': False,
#   'runtime': 244850603761,
#   'ground': 7344226304,
#   'error': 0.03141062250142775,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 8571070709.76,
#   'oom': True,
#   'runtime': 889000704,
#   'ground': 4733272064,
#   'error': 0.810813026140895,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 4706009088,
#   'oom': False,
#   'runtime': 12228272128,
#   'ground': 4733272064,
#   'error': 0.0057598582188746125,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.00664599025254763}},
#  {'tool': 'DNNmem',
#   'memory': 4424990720,
#   'oom': False,
#   'runtime': 17159469673,
#   'ground': 4733272064,
#   'error': 0.06513070447496677,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.013735046521931768}},
#  {'tool': 'SchedTune',
#   'memory': 14503976632.32,
#   'oom': True,
#   'runtime': 4199374189,
#   'ground': 7558135808,
#   'error': 0.9189886237513873,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8462008320,
#   'oom': True,
#   'runtime': 28965659424,
#   'ground': 7558135808,
#   'error': 0.11958934517203108,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8403288064,
#   'oom': True,
#   'runtime': 85539882271,
#   'ground': 7558135808,
#   'error': 0.11182019977802442,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9035191418.88,
#   'oom': True,
#   'runtime': 1027967008,
#   'ground': 5676990464,
#   'error': 0.5915459918729219,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 5620367360,
#   'oom': False,
#   'runtime': 13965376780,
#   'ground': 5676990464,
#   'error': 0.009974141115626155,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03620243812338382}},
#  {'tool': 'DNNmem',
#   'memory': 5261754368,
#   'oom': False,
#   'runtime': 18529725938,
#   'ground': 5676990464,
#   'error': 0.0731437015145918,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.009974141115626155}},
#  {'tool': 'SchedTune',
#   'memory': 14503976632.32,
#   'oom': True,
#   'runtime': 4813847566,
#   'ground': 7866417152,
#   'error': 0.8437843241802185,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8225030144,
#   'oom': True,
#   'runtime': 32515761090,
#   'ground': 7866417152,
#   'error': 0.045587843241802185,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8302624768,
#   'oom': False,
#   'runtime': 91092617947,
#   'ground': 7866417152,
#   'error': 0.05545187949880032,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9270858874.88,
#   'oom': True,
#   'runtime': 1415590155,
#   'ground': 7962886144,
#   'error': 0.164258625230445,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8155824128,
#   'oom': False,
#   'runtime': 21630044418,
#   'ground': 7962886144,
#   'error': 0.024229654990782196,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03107716618382934}},
#  {'tool': 'DNNmem',
#   'memory': 6962544640,
#   'oom': False,
#   'runtime': 22733355811,
#   'ground': 7962886144,
#   'error': 0.12562549381090335,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 12231701954.56,
#   'oom': True,
#   'runtime': 1701141843,
#   'ground': 8134852608,
#   'error': 0.5036169115751482,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8415870976,
#   'oom': True,
#   'runtime': 20914390829,
#   'ground': 8134852608,
#   'error': 0.034544985821087906,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8361345024,
#   'oom': True,
#   'runtime': 19184678334,
#   'ground': 8134852608,
#   'error': 0.027842227378190254,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9248304005.12,
#   'oom': True,
#   'runtime': 1199402146,
#   'ground': 7205814272,
#   'error': 0.2834502328288709,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 6276775936,
#   'oom': False,
#   'runtime': 27537311941,
#   'ground': 7205814272,
#   'error': 0.12892898719441212,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05325960419091967}},
#  {'tool': 'DNNmem',
#   'memory': 6568280064,
#   'oom': False,
#   'runtime': 45642594848,
#   'ground': 7205814272,
#   'error': 0.08847497089639116,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.002037252619324796}},
#  {'tool': 'SchedTune',
#   'memory': 6849067745.28,
#   'oom': False,
#   'runtime': 2288537853,
#   'ground': 9374269440,
#   'error': 0.2693758389261745,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05456152125279639}},
#  {'tool': 'solution',
#   'memory': 8222932992,
#   'oom': False,
#   'runtime': 5585803204,
#   'ground': 9374269440,
#   'error': 0.12281879194630872,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.02505592841163311}},
#  {'tool': 'DNNmem',
#   'memory': 6278873088,
#   'oom': False,
#   'runtime': 33937620588,
#   'ground': 9374269440,
#   'error': 0.3302013422818792,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.052796420581655484}},
#  {'tool': 'SchedTune',
#   'memory': 5924884316.16,
#   'oom': False,
#   'runtime': 2082510523,
#   'ground': 7142899712,
#   'error': 0.17052113916617737,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 7486832640,
#   'oom': False,
#   'runtime': 5216683006,
#   'ground': 7142899712,
#   'error': 0.048150322959483266,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.15502055196711687}},
#  {'tool': 'DNNmem',
#   'memory': 6306136064,
#   'oom': False,
#   'runtime': 32746851815,
#   'ground': 7142899712,
#   'error': 0.11714621256605989,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 2778076282.88,
#   'oom': False,
#   'runtime': 483727066,
#   'ground': 1988100096,
#   'error': 0.39735232067510556,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.2897573839662448}},
#  {'tool': 'solution',
#   'memory': 2004877312,
#   'oom': False,
#   'runtime': 13563752118,
#   'ground': 1988100096,
#   'error': 0.008438818565400843,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04219409282700422}},
#  {'tool': 'DNNmem',
#   'memory': 1707081728,
#   'oom': False,
#   'runtime': 11352208505,
#   'ground': 1988100096,
#   'error': 0.14135021097046413,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 2409040445.44,
#   'oom': False,
#   'runtime': 399131171,
#   'ground': 1266679808,
#   'error': 0.9018543046357617,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.9697350993377484}},
#  {'tool': 'solution',
#   'memory': 1249902592,
#   'oom': False,
#   'runtime': 11705330761,
#   'ground': 1266679808,
#   'error': 0.013245033112582781,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.018211920529801324}},
#  {'tool': 'DNNmem',
#   'memory': 1214251008,
#   'oom': False,
#   'runtime': 39380275348,
#   'ground': 1266679808,
#   'error': 0.041390728476821195,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03145695364238411}},
#  {'tool': 'SchedTune',
#   'memory': 2677968732.16,
#   'oom': False,
#   'runtime': 445185279,
#   'ground': 1619001344,
#   'error': 0.6540867875647668,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.5996826424870465}},
#  {'tool': 'solution',
#   'memory': 1646264320,
#   'oom': False,
#   'runtime': 12358859466,
#   'ground': 1619001344,
#   'error': 0.01683937823834197,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.02461139896373057}},
#  {'tool': 'DNNmem',
#   'memory': 1725956096,
#   'oom': False,
#   'runtime': 39869723497,
#   'ground': 1619001344,
#   'error': 0.06606217616580311,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.06606217616580311}},
#  {'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 3166934341,
#   'ground': 12404654080,
#   'error': 0.05902620456466616,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12901679104,
#   'oom': True,
#   'runtime': 39390190849,
#   'ground': 12404654080,
#   'error': 0.0400676246830093,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12907970560,
#   'oom': True,
#   'runtime': 227109988234,
#   'ground': 12404654080,
#   'error': 0.04057480980557904,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10756303093.76,
#   'oom': False,
#   'runtime': 3982090657,
#   'ground': 11752439808,
#   'error': 0.08475999286224124,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 13063159808,
#   'oom': True,
#   'runtime': 10823379302,
#   'ground': 11752439808,
#   'error': 0.11152748037116346,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 10762584064,
#   'oom': False,
#   'runtime': 38751698534,
#   'ground': 11752439808,
#   'error': 0.08422555317630265,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05817273376159886}},
#  {'tool': 'SchedTune',
#   'memory': 13554365235.2,
#   'oom': True,
#   'runtime': 3129490598,
#   'ground': 12262047744,
#   'error': 0.10539165383957591,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12792627200,
#   'oom': True,
#   'runtime': 27973546457,
#   'ground': 12262047744,
#   'error': 0.04327005301864204,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 11767119872,
#   'oom': False,
#   'runtime': 78432637122,
#   'ground': 12262047744,
#   'error': 0.04036257910039336,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 4621822934,
#   'ground': 8082423808,
#   'error': 0.6212013492475349,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8424259584,
#   'oom': True,
#   'runtime': 36150963254,
#   'ground': 8082423808,
#   'error': 0.04229372080954852,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8405385216,
#   'oom': True,
#   'runtime': 235009314669,
#   'ground': 8082423808,
#   'error': 0.03995848469122989,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 8101424005.12,
#   'oom': False,
#   'runtime': 884451452,
#   'ground': 5047844864,
#   'error': 0.6049272953884504,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.5691981719983381}},
#  {'tool': 'solution',
#   'memory': 4729077760,
#   'oom': False,
#   'runtime': 25988059980,
#   'ground': 5047844864,
#   'error': 0.06314914831740756,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03822185292895721}},
#  {'tool': 'DNNmem',
#   'memory': 4647288832,
#   'oom': False,
#   'runtime': 43705252959,
#   'ground': 5047844864,
#   'error': 0.0793518903199003,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.012463647694225177}},
#  {'tool': 'SchedTune',
#   'memory': 9118270095.36,
#   'oom': False,
#   'runtime': 1218673838,
#   'ground': 7652507648,
#   'error': 0.1915401479857496,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.1430337078651686}},
#  {'tool': 'solution',
#   'memory': 7419723776,
#   'oom': False,
#   'runtime': 12173364667,
#   'ground': 7652507648,
#   'error': 0.030419292956974514,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0057550013702384216}},
#  {'tool': 'DNNmem',
#   'memory': 5314183168,
#   'oom': False,
#   'runtime': 22061405356,
#   'ground': 7652507648,
#   'error': 0.30556316799123046,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10734597570.56,
#   'oom': False,
#   'runtime': 4492860554,
#   'ground': 11892948992,
#   'error': 0.09739816610827019,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 14304673792,
#   'oom': True,
#   'runtime': 11999813296,
#   'ground': 11892948992,
#   'error': 0.2027861047434315,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 13677625344,
#   'oom': True,
#   'runtime': 40289734227,
#   'ground': 11892948992,
#   'error': 0.1500617175101393,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 3118419271,
#   'ground': 12337545216,
#   'error': 0.0647866734659188,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12863930368,
#   'oom': True,
#   'runtime': 21341039343,
#   'ground': 12337545216,
#   'error': 0.04266530681625021,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12448694272,
#   'oom': False,
#   'runtime': 111052990073,
#   'ground': 12337545216,
#   'error': 0.009009009009009009,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.009009009009009009}},
#  {'tool': 'SchedTune',
#   'memory': 4677351505.92,
#   'oom': False,
#   'runtime': 664899829,
#   'ground': 3615490048,
#   'error': 0.2936977958236659,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.3174796983758701}},
#  {'tool': 'solution',
#   'memory': 3342860288,
#   'oom': False,
#   'runtime': 20192722735,
#   'ground': 3615490048,
#   'error': 0.07540603248259861,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05278422273781903}},
#  {'tool': 'DNNmem',
#   'memory': 3277848576,
#   'oom': False,
#   'runtime': 42178237387,
#   'ground': 3615490048,
#   'error': 0.09338747099767981,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0034802784222737818}},
#  {'tool': 'SchedTune',
#   'memory': 12982796943.36,
#   'oom': True,
#   'runtime': 5531509824,
#   'ground': 6723469312,
#   'error': 0.9309669369931379,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8151629824,
#   'oom': True,
#   'runtime': 15426447718,
#   'ground': 6723469312,
#   'error': 0.2124142233312539,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8436842496,
#   'oom': True,
#   'runtime': 44002743335,
#   'ground': 6723469312,
#   'error': 0.25483468496568934,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 4448719994.88,
#   'oom': False,
#   'runtime': 773157167,
#   'ground': 4452253696,
#   'error': 0.0007936881771078405,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.02040273198304289}},
#  {'tool': 'solution',
#   'memory': 4343201792,
#   'oom': False,
#   'runtime': 12662635217,
#   'ground': 4452253696,
#   'error': 0.024493641073951956,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.046632124352331605}},
#  {'tool': 'DNNmem',
#   'memory': 3728736256,
#   'oom': False,
#   'runtime': 19443570526,
#   'ground': 4452253696,
#   'error': 0.16250588789448894,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9115197767.68,
#   'oom': False,
#   'runtime': 1176547210,
#   'ground': 7071596544,
#   'error': 0.2889872479240807,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.291952846975089}},
#  {'tool': 'solution',
#   'memory': 6801063936,
#   'oom': False,
#   'runtime': 17888628955,
#   'ground': 7071596544,
#   'error': 0.03825622775800712,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.029062870699881376}},
#  {'tool': 'DNNmem',
#   'memory': 5827985408,
#   'oom': False,
#   'runtime': 21479433558,
#   'ground': 7071596544,
#   'error': 0.1758600237247924,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 2513981931.52,
#   'oom': False,
#   'runtime': 432893016,
#   'ground': 2032140288,
#   'error': 0.23711042311661507,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.2205985552115583}},
#  {'tool': 'solution',
#   'memory': 1887436800,
#   'oom': False,
#   'runtime': 12780799860,
#   'ground': 2032140288,
#   'error': 0.07120743034055728,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04437564499484004}},
#  {'tool': 'DNNmem',
#   'memory': 1619001344,
#   'oom': False,
#   'runtime': 11172367749,
#   'ground': 2032140288,
#   'error': 0.20330237358101136,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10755107717.12,
#   'oom': False,
#   'runtime': 1795056567,
#   'ground': 11848908800,
#   'error': 0.09231238938053091,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 11930697728,
#   'oom': False,
#   'runtime': 17697043020,
#   'ground': 11848908800,
#   'error': 0.006902654867256637,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0033628318584070795}},
#  {'tool': 'DNNmem',
#   'memory': 8369733632,
#   'oom': False,
#   'runtime': 25962333797,
#   'ground': 11848908800,
#   'error': 0.2936283185840708,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10755107717.12,
#   'oom': False,
#   'runtime': 1792434788,
#   'ground': 12010389504,
#   'error': 0.1045163261742622,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12106858496,
#   'oom': False,
#   'runtime': 17692580648,
#   'ground': 12010389504,
#   'error': 0.008032128514056224,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.004539898725336127}},
#  {'tool': 'DNNmem',
#   'memory': 8506048512,
#   'oom': False,
#   'runtime': 26910143347,
#   'ground': 12010389504,
#   'error': 0.29177579884756416,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 3600432496.64,
#   'oom': False,
#   'runtime': 570290335,
#   'ground': 2476736512,
#   'error': 0.4537002540220152,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.4621676545300592}},
#  {'tool': 'solution',
#   'memory': 2478833664,
#   'oom': False,
#   'runtime': 14526698370,
#   'ground': 2476736512,
#   'error': 0.000846740050804403,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.011854360711261643}},
#  {'tool': 'DNNmem',
#   'memory': 2648702976,
#   'oom': False,
#   'runtime': 40558009394,
#   'ground': 2476736512,
#   'error': 0.06943268416596104,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.06943268416596104}},
#  {'tool': 'SchedTune',
#   'memory': 9270858874.88,
#   'oom': True,
#   'runtime': 1170035118,
#   'ground': 7941914624,
#   'error': 0.16733298125165028,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8380219392,
#   'oom': True,
#   'runtime': 14122941675,
#   'ground': 7941914624,
#   'error': 0.05518880380248217,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 6106906624,
#   'oom': False,
#   'runtime': 15779851996,
#   'ground': 7941914624,
#   'error': 0.23105360443622922,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 5221154229,
#   'ground': 7839154176,
#   'error': 0.6715115034777955,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8260681728,
#   'oom': True,
#   'runtime': 29284912669,
#   'ground': 7839154176,
#   'error': 0.05377207062600321,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8258584576,
#   'oom': False,
#   'runtime': 144533746517,
#   'ground': 7839154176,
#   'error': 0.05350454788657036,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 3739001815.04,
#   'oom': False,
#   'runtime': 558541729,
#   'ground': 2665480192,
#   'error': 0.4027498033044846,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.42714004720692367}},
#  {'tool': 'solution',
#   'memory': 2686451712,
#   'oom': False,
#   'runtime': 8842392492,
#   'ground': 2665480192,
#   'error': 0.007867820613690008,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.025177025963808025}},
#  {'tool': 'DNNmem',
#   'memory': 2503999488,
#   'oom': False,
#   'runtime': 15371377806,
#   'ground': 2665480192,
#   'error': 0.06058221872541306,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.01809598741148702}},
#  {'tool': 'SchedTune',
#   'memory': 10221959249.92,
#   'oom': False,
#   'runtime': 3858417390,
#   'ground': 11821645824,
#   'error': 0.1353184317899592,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 14269022208,
#   'oom': True,
#   'runtime': 12360253590,
#   'ground': 11821645824,
#   'error': 0.20702501330494943,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 13058965504,
#   'oom': True,
#   'runtime': 33930061627,
#   'ground': 11821645824,
#   'error': 0.10466560227071137,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 14503976632.32,
#   'oom': True,
#   'runtime': 4408955399,
#   'ground': 7845445632,
#   'error': 0.8487129109863673,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8449425408,
#   'oom': True,
#   'runtime': 33927459147,
#   'ground': 7845445632,
#   'error': 0.07698476343223737,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8474591232,
#   'oom': True,
#   'runtime': 87185426662,
#   'ground': 7845445632,
#   'error': 0.08019246190858059,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 12306727567.36,
#   'oom': False,
#   'runtime': 1711144321,
#   'ground': 12421431296,
#   'error': 0.009234340705723402,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0029875063312510062}},
#  {'tool': 'solution',
#   'memory': 12400459776,
#   'oom': False,
#   'runtime': 21545196492,
#   'ground': 12421431296,
#   'error': 0.0016883336147222692,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.013506668917778153}},
#  {'tool': 'DNNmem',
#   'memory': 9518972928,
#   'oom': False,
#   'runtime': 18923390802,
#   'ground': 12421431296,
#   'error': 0.23366537227756204,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9103590031.36,
#   'oom': True,
#   'runtime': 1188911008,
#   'ground': 7765753856,
#   'error': 0.1722738320280854,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 7480541184,
#   'oom': False,
#   'runtime': 19617893480,
#   'ground': 7765753856,
#   'error': 0.03672697812584391,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.029435592762624897}},
#  {'tool': 'DNNmem',
#   'memory': 6415187968,
#   'oom': False,
#   'runtime': 22135258124,
#   'ground': 7765753856,
#   'error': 0.17391304347826086,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 3279547269.12,
#   'oom': False,
#   'runtime': 512516438,
#   'ground': 2344615936,
#   'error': 0.39875670840787114,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.32004472271914125}},
#  {'tool': 'solution',
#   'memory': 2319450112,
#   'oom': False,
#   'runtime': 14551532795,
#   'ground': 2344615936,
#   'error': 0.01073345259391771,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.052772808586762074}},
#  {'tool': 'DNNmem',
#   'memory': 2273312768,
#   'oom': False,
#   'runtime': 40359315984,
#   'ground': 2344615936,
#   'error': 0.03041144901610018,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.028622540250447227}},
#  {'tool': 'SchedTune',
#   'memory': 3755474944.0,
#   'oom': False,
#   'runtime': 588293681,
#   'ground': 2996830208,
#   'error': 0.25314905528341497,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.16567529741077677}},
#  {'tool': 'solution',
#   'memory': 2919235584,
#   'oom': False,
#   'runtime': 17510186191,
#   'ground': 2996830208,
#   'error': 0.02589223233030091,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.02729181245626312}},
#  {'tool': 'DNNmem',
#   'memory': 2879389696,
#   'oom': False,
#   'runtime': 41193226695,
#   'ground': 2996830208,
#   'error': 0.03918824352694192,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.021693491952414275}},
#  {'tool': 'SchedTune',
#   'memory': 8201709813.76,
#   'oom': False,
#   'runtime': 1817575831,
#   'ground': 10420748288,
#   'error': 0.21294425437713824,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 9770631168,
#   'oom': False,
#   'runtime': 23244860307,
#   'ground': 10420748288,
#   'error': 0.06238679814852083,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 6637486080,
#   'oom': False,
#   'runtime': 73601308807,
#   'ground': 10420748288,
#   'error': 0.3630509156771986,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 4231476019.2,
#   'oom': False,
#   'runtime': 830712198,
#   'ground': 4372561920,
#   'error': 0.03226618705035975,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.003705035971222978}},
#  {'tool': 'solution',
#   'memory': 4555014144,
#   'oom': False,
#   'runtime': 9234245235,
#   'ground': 4372561920,
#   'error': 0.041726618705035974,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04028776978417266}},
#  {'tool': 'DNNmem',
#   'memory': 3267362816,
#   'oom': False,
#   'runtime': 16360946827,
#   'ground': 4372561920,
#   'error': 0.252757793764988,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10158834974.72,
#   'oom': True,
#   'runtime': 2059950586,
#   'ground': 7841251328,
#   'error': 0.2955629847552821,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8464105472,
#   'oom': True,
#   'runtime': 26836037751,
#   'ground': 7841251328,
#   'error': 0.07943300347686547,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 7763656704,
#   'oom': False,
#   'runtime': 74985288129,
#   'ground': 7841251328,
#   'error': 0.009895694035838459,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13136853729.28,
#   'oom': True,
#   'runtime': 2733918399,
#   'ground': 11725176832,
#   'error': 0.12039706671436243,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 11398021120,
#   'oom': False,
#   'runtime': 18462850720,
#   'ground': 11725176832,
#   'error': 0.027901985333571813,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.01860132355571454}},
#  {'tool': 'DNNmem',
#   'memory': 11333009408,
#   'oom': False,
#   'runtime': 126346716146,
#   'ground': 11725176832,
#   'error': 0.03344661062421749,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.01717045251296727}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 3740134312,
#   'ground': 8074035200,
#   'error': 0.6228857142857142,
# ...
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8279556096,
#   'oom': False,
#   'runtime': 152070492816,
#   'ground': 8019509248,
#   'error': 0.032426778242677826,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 5341813145.6,
#   'oom': False,
#   'runtime': 1842953794,
#   'ground': 9846128640,
#   'error': 0.4574707135250266,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 6996099072,
#   'oom': False,
#   'runtime': 5349174830,
#   'ground': 9846128640,
#   'error': 0.28945686900958467,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0268370607028754}},
#  {'tool': 'DNNmem',
#   'memory': 5729419264,
#   'oom': False,
#   'runtime': 26870460802,
#   'ground': 9846128640,
#   'error': 0.41810436634717785,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 5556823654.4,
#   'oom': False,
#   'runtime': 804040884,
#   'ground': 5066719232,
#   'error': 0.09673013245033105,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.1261175496688741}},
#  {'tool': 'solution',
#   'memory': 4976541696,
#   'oom': False,
#   'runtime': 14364669228,
#   'ground': 5066719232,
#   'error': 0.017798013245033113,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.05380794701986755}},
#  {'tool': 'DNNmem',
#   'memory': 4217372672,
#   'oom': False,
#   'runtime': 19850711874,
#   'ground': 5066719232,
#   'error': 0.16763245033112584,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10744475156.48,
#   'oom': True,
#   'runtime': 1444869478,
#   'ground': 8160018432,
#   'error': 0.316721922384991,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8438939648,
#   'oom': True,
#   'runtime': 18640718665,
#   'ground': 8160018432,
#   'error': 0.034181444358776666,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 7384072192,
#   'oom': False,
#   'runtime': 16949026909,
#   'ground': 8160018432,
#   'error': 0.09509123618607042,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 4758581016,
#   'ground': 8050966528,
#   'error': 0.6275358166189111,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8401190912,
#   'oom': True,
#   'runtime': 32486906512,
#   'ground': 8050966528,
#   'error': 0.0435009116957541,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8443133952,
#   'oom': True,
#   'runtime': 296946339327,
#   'ground': 8050966528,
#   'error': 0.04871060171919771,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 13103236382.72,
#   'oom': True,
#   'runtime': 3425339324,
#   'ground': 8067743744,
#   'error': 0.6241512867169222,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8434745344,
#   'oom': True,
#   'runtime': 34108307781,
#   'ground': 8067743744,
#   'error': 0.04548999220171562,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8405385216,
#   'oom': True,
#   'runtime': 293699723521,
#   'ground': 8067743744,
#   'error': 0.041850792825578374,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10177457684.48,
#   'oom': True,
#   'runtime': 3937245341,
#   'ground': 6704594944,
#   'error': 0.5179824835783546,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8363442176,
#   'oom': True,
#   'runtime': 12346079666,
#   'ground': 6704594944,
#   'error': 0.24741945573975602,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8048869376,
#   'oom': False,
#   'runtime': 33473218324,
#   'ground': 6704594944,
#   'error': 0.2005004691898655,
#   'real_oom': True,
#   'correct_estimation': False,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10166353264.64,
#   'oom': True,
#   'runtime': 4396141862,
#   'ground': 7432306688,
#   'error': 0.36785976297968387,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 8331984896,
#   'oom': True,
#   'runtime': 14638662560,
#   'ground': 7432306688,
#   'error': 0.12104966139954854,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 8441036800,
#   'oom': True,
#   'runtime': 35747639834,
#   'ground': 7432306688,
#   'error': 0.13572234762979685,
#   'real_oom': True,
#   'correct_estimation': True,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9035191418.88,
#   'oom': True,
#   'runtime': 1067043680,
#   'ground': 5670699008,
#   'error': 0.5933117603550294,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'solution',
#   'memory': 5538578432,
#   'oom': False,
#   'runtime': 14265093548,
#   'ground': 5670699008,
#   'error': 0.02329881656804734,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.028106508875739646}},
#  {'tool': 'DNNmem',
#   'memory': 5184159744,
#   'oom': False,
#   'runtime': 18194107312,
#   'ground': 5670699008,
#   'error': 0.08579881656804733,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.01220414201183432}},
#  {'tool': 'SchedTune',
#   'memory': 10308613570.56,
#   'oom': False,
#   'runtime': 3691187532,
#   'ground': 11412701184,
#   'error': 0.09674200661521504,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12727615488,
#   'oom': True,
#   'runtime': 9418956957,
#   'ground': 11412701184,
#   'error': 0.11521499448732084,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 10152312832,
#   'oom': False,
#   'runtime': 37293569656,
#   'ground': 11412701184,
#   'error': 0.11043733921352444,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10756303093.76,
#   'oom': False,
#   'runtime': 4037428351,
#   'ground': 11909726208,
#   'error': 0.09684715618946996,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 14602469376,
#   'oom': True,
#   'runtime': 10987040531,
#   'ground': 11909726208,
#   'error': 0.22609614368726888,
#   'real_oom': False,
#   'correct_estimation': False,
#   '2nd verification': {'oom': None, 'error': None}},
#  {'tool': 'DNNmem',
#   'memory': 12262047744,
#   'oom': False,
#   'runtime': 38792132624,
#   'ground': 11909726208,
#   'error': 0.029582673005810883,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04578270822327875}},
#  {'tool': 'SchedTune',
#   'memory': 2144925122.56,
#   'oom': False,
#   'runtime': 388531607,
#   'ground': 1474297856,
#   'error': 0.4548790896159317,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.3467709815078236}},
#  {'tool': 'solution',
#   'memory': 1398800384,
#   'oom': False,
#   'runtime': 9623656558,
#   'ground': 1474297856,
#   'error': 0.051209103840682786,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03840682788051209}},
#  {'tool': 'DNNmem',
#   'memory': 1201668096,
#   'oom': False,
#   'runtime': 10462438525,
#   'ground': 1474297856,
#   'error': 0.18492176386913228,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 4677351505.92,
#   'oom': False,
#   'runtime': 696462409,
#   'ground': 3644850176,
#   'error': 0.28327675489067894,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.28327675489067894}},
#  {'tool': 'solution',
#   'memory': 3428843520,
#   'oom': False,
#   'runtime': 17332310487,
#   'ground': 3644850176,
#   'error': 0.059263521288837745,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.039125431530494824}},
#  {'tool': 'DNNmem',
#   'memory': 3623878656,
#   'oom': False,
#   'runtime': 42516568662,
#   'ground': 3644850176,
#   'error': 0.005753739930955121,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0011507479861910242}},
#  {'tool': 'SchedTune',
#   'memory': 2493314498.56,
#   'oom': False,
#   'runtime': 511042604,
#   'ground': 2153775104,
#   'error': 0.15764849074975654,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.1391480038948393}},
#  {'tool': 'solution',
#   'memory': 1979711488,
#   'oom': False,
#   'runtime': 13639468642,
#   'ground': 2153775104,
#   'error': 0.08081791626095423,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.011684518013631937}},
#  {'tool': 'DNNmem',
#   'memory': 1692401664,
#   'oom': False,
#   'runtime': 10949688871,
#   'ground': 2153775104,
#   'error': 0.21421616358325218,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 5530053509.12,
#   'oom': False,
#   'runtime': 817814575,
#   'ground': 4018143232,
#   'error': 0.37627087682672233,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.3527844467640918}},
#  {'tool': 'solution',
#   'memory': 3854565376,
#   'oom': False,
#   'runtime': 19318111121,
#   'ground': 4018143232,
#   'error': 0.0407098121085595,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.031315240083507306}},
#  {'tool': 'DNNmem',
#   'memory': 4034920448,
#   'oom': False,
#   'runtime': 42834754370,
#   'ground': 4018143232,
#   'error': 0.0041753653444676405,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0041753653444676405}},
#  {'tool': 'SchedTune',
#   'memory': 8062354063.36,
#   'oom': False,
#   'runtime': 2403887021,
#   'ground': 11593056256,
#   'error': 0.3045531837916064,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.040779667149059305}},
#  {'tool': 'solution',
#   'memory': 9829351424,
#   'oom': False,
#   'runtime': 6763594081,
#   'ground': 11593056256,
#   'error': 0.15213458755426917,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.11577424023154848}},
#  {'tool': 'DNNmem',
#   'memory': 7446986752,
#   'oom': False,
#   'runtime': 28630150492,
#   'ground': 11593056256,
#   'error': 0.35763386396526775,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 10182574735.36,
#   'oom': False,
#   'runtime': 2099615259,
#   'ground': 12287213568,
#   'error': 0.17128690902884447,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'solution',
#   'memory': 12209618944,
#   'oom': False,
#   'runtime': 25737080679,
#   'ground': 12287213568,
#   'error': 0.006315070831199863,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0017067759003242873}},
#  {'tool': 'DNNmem',
#   'memory': 8053063680,
#   'oom': False,
#   'runtime': 74976051491,
#   'ground': 12287213568,
#   'error': 0.34459805427547363,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 2492790210.56,
#   'oom': False,
#   'runtime': 451496415,
#   'ground': 2176843776,
#   'error': 0.1451396917148362,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.09986030828516375}},
#  {'tool': 'solution',
#   'memory': 2116026368,
#   'oom': False,
#   'runtime': 13757575060,
#   'ground': 2176843776,
#   'error': 0.027938342967244702,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.0394990366088632}},
#  {'tool': 'DNNmem',
#   'memory': 1799356416,
#   'oom': False,
#   'runtime': 11379407300,
#   'ground': 2176843776,
#   'error': 0.17341040462427745,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 9115197767.68,
#   'oom': False,
#   'runtime': 1175218946,
#   'ground': 6455033856,
#   'error': 0.4121068875893438,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.3377079272254711}},
#  {'tool': 'solution',
#   'memory': 6037700608,
#   'oom': False,
#   'runtime': 25785934914,
#   'ground': 6455033856,
#   'error': 0.06465237166991553,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.043209876543209874}},
#  {'tool': 'DNNmem',
#   'memory': 6392119296,
#   'oom': False,
#   'runtime': 44822946318,
#   'ground': 6455033856,
#   'error': 0.009746588693957114,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.03996101364522417}},
#  {'tool': 'SchedTune',
#   'memory': 2513981931.52,
#   'oom': False,
#   'runtime': 458826660,
#   'ground': 1998585856,
#   'error': 0.2578803777544596,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.21905561385099684}},
#  {'tool': 'solution',
#   'memory': 1841299456,
#   'oom': False,
#   'runtime': 13098737096,
#   'ground': 1998585856,
#   'error': 0.07869884575026233,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04197271773347324}},
#  {'tool': 'DNNmem',
#   'memory': 1591738368,
#   'oom': False,
#   'runtime': 11260217995,
#   'ground': 1998585856,
#   'error': 0.20356768100734524,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': True, 'error': None}},
#  {'tool': 'SchedTune',
#   'memory': 4531316326.4,
#   'oom': False,
#   'runtime': 587958383,
#   'ground': 3537895424,
#   'error': 0.2807943094250147,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.16164789567279184}},
#  {'tool': 'solution',
#   'memory': 3491758080,
#   'oom': False,
#   'runtime': 11207453725,
#   'ground': 3537895424,
#   'error': 0.013040901007705987,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.04445761707172496}},
#  {'tool': 'DNNmem',
#   'memory': 3019898880,
#   'oom': False,
#   'runtime': 18668362789,
#   'ground': 3537895424,
#   'error': 0.14641375222288086,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.00948429164196799}},
#  {'tool': 'SchedTune',
#   'memory': 2778076282.88,
#   'oom': False,
#   'runtime': 477311713,
#   'ground': 1933574144,
#   'error': 0.4367570498915402,
#   'real_oom': False,
#   'correct_estimation': True,
#   '2nd verification': {'oom': False, 'error': 0.3380585683297181}},
#  ...]

# %%
project_base = Path().home().joinpath(config.run_id)
# project_base = Path().home().joinpath("/Users/jiaboshi/Google Drive/My Drive/101-ResearchData/002-xMem-LLm/100-Experiments/001-Anova/CNN 3060")
# project_base = Path().home().joinpath('xMemExperiments')

# %%
e_plot = ExperimentPlot(output_dir=project_base)

# %%
fig = e_plot.llm_plot_relative_error_in_box_diagram_with_verification_data(
    title="Evaluation-Relative Error Experiments Result across Estimators-SGD",
    data_dir=project_base,
    overall_median=False,
    image_size=(1000, 400),
    font_size=20,
    legend_font_size=18,
    tickfont_size=22,
    view_mode = False,
    yrange=(0, 200),
)
fig.show()
# Out:
# <div>                            <div id="38aad3d2-b275-45c7-a6c3-3d512ac1c172" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38aad3d2-b275-45c7-a6c3-3d512ac1c172")) {                    Plotly.newPlot(                        "38aad3d2-b275-45c7-a6c3-3d512ac1c172",                        [{"alignmentgroup":"True","hovertemplate":"Estimator=SchedTune\u003cbr\u003eModel=%{x}\u003cbr\u003eError=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","size":3},"name":"SchedTune","notched":false,"offsetgroup":"SchedTune","orientation":"v","showlegend":true,"x":["ResNet101","VGG19","MnasNet","VGG16","ResNet101","RegNetX400MF","VGG16","RegNetX400MF","VGG16","ConvNeXtBase","ResNet152","ResNet101","ConvNeXtTiny","MobileNetV2","MnasNet","ResNet152","ConvNeXtTiny","ResNet101","VGG19","ResNet152","MnasNet","ConvNeXtBase","MnasNet","ConvNeXtBase","MobeNetV3Large","MobileNetV2","RegNetY400MF","VGG19","VGG19","MobeNetV3Small","RegNetX400MF","RegNetY400MF","ResNet152","VGG19","ConvNeXtBase","ResNet152","RegNetX400MF","ConvNeXtTiny","VGG19","ResNet101","RegNetX400MF","VGG19","MobeNetV3Large","MobeNetV3Large","MobeNetV3Small","ConvNeXtTiny","ConvNeXtTiny","RegNetY400MF","MobileNetV2","ResNet101","MnasNet","VGG16","ConvNeXtBase","MobileNetV2","MobeNetV3Large","RegNetX400MF","RegNetX400MF","ConvNeXtBase","ConvNeXtTiny","ConvNeXtBase","ResNet101","ResNet152","VGG16","MnasNet","VGG19","ConvNeXtBase","MobileNetV2","ResNet101","ConvNeXtTiny","MnasNet","ConvNeXtBase","MobeNetV3Small","RegNetY400MF","VGG19","ResNet101","MobeNetV3Large","RegNetY400MF","VGG16","RegNetX400MF","ConvNeXtBase","MobeNetV3Small","MobileNetV2","ConvNeXtBase","ResNet152","VGG19","RegNetY400MF","RegNetY400MF","ConvNeXtTiny","MobeNetV3Small","VGG16","RegNetX400MF","ConvNeXtBase","MobileNetV2","VGG19","ResNet152","ResNet152","VGG16","ResNet152","RegNetY400MF","ConvNeXtTiny","ResNet152","ResNet152","ResNet152","RegNetY400MF","MobeNetV3Large","RegNetY400MF","ConvNeXtTiny","ConvNeXtBase","ConvNeXtTiny","ConvNeXtTiny","VGG16","RegNetX400MF","MobeNetV3Large","RegNetX400MF","MobileNetV2","ConvNeXtTiny","MobeNetV3Large","MobileNetV2","VGG16","ConvNeXtTiny","MobeNetV3Large","ResNet152","MobeNetV3Small","RegNetX400MF","ResNet101","ConvNeXtBase","MobeNetV3Large","MobileNetV2","VGG16","RegNetX400MF","ResNet101","MobeNetV3Small","ConvNeXtTiny","MobeNetV3Large","RegNetX400MF","MobileNetV2","ResNet101","VGG16","MobileNetV2","RegNetX400MF","ResNet152","RegNetY400MF","ResNet152","ResNet101","MobileNetV2","VGG19","RegNetX400MF","RegNetY400MF","ResNet152","ConvNeXtBase","RegNetY400MF","RegNetX400MF","RegNetX400MF","ConvNeXtTiny","MobeNetV3Small","RegNetY400MF","MobeNetV3Small","VGG16","ResNet152","MobileNetV2","ConvNeXtBase","VGG19","MobeNetV3Small","ResNet101","MobeNetV3Large","VGG19","RegNetX400MF","VGG19","MobileNetV2","MobeNetV3Small","MobeNetV3Small","MnasNet","ResNet152","VGG16","RegNetY400MF","MobeNetV3Small","ConvNeXtBase","ConvNeXtBase","ConvNeXtTiny","MobeNetV3Small","ConvNeXtTiny","MnasNet","VGG19","ResNet101","ConvNeXtBase","MobileNetV2","MobileNetV2","MobileNetV2","RegNetX400MF","MobeNetV3Small","MobeNetV3Small","MnasNet","ResNet152","MobeNetV3Large","ConvNeXtTiny","ResNet101","MnasNet","VGG16","MobileNetV2","ConvNeXtTiny","VGG16","VGG16","RegNetY400MF","ConvNeXtTiny","MnasNet","ConvNeXtTiny","RegNetX400MF","RegNetX400MF","ResNet101","VGG19","ConvNeXtTiny","RegNetX400MF","ConvNeXtTiny","ResNet101","MobeNetV3Large","RegNetY400MF","ConvNeXtBase","VGG19","VGG19","MobileNetV2","MnasNet","RegNetY400MF","MnasNet","VGG19","MobileNetV2","VGG19","RegNetY400MF","MobileNetV2","ResNet152","MobeNetV3Large","MnasNet","ConvNeXtTiny","MobeNetV3Large","MobeNetV3Small","MnasNet","ResNet101","RegNetY400MF","MobeNetV3Large", ...

# %%
fig = e_plot.llm_plot_probability_estimation_vs_error_scatter_diagram_model_base(
    title="Evaluation-Comparison of Success Rate vs Relative Error-SGD",
    data_dir=project_base,
    image_size=(800, 800),
    title_font_size=35,
    legend_font_size=30,
    tickfont_size=25,
    quadrant_font_size=40,
    marker_size=16,
    view_mode=True
)
fig.show()
# Out:
# <div>                            <div id="4fea74f9-961d-447a-9216-66df0e3aacdb" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fea74f9-961d-447a-9216-66df0e3aacdb")) {                    Plotly.newPlot(                        "4fea74f9-961d-447a-9216-66df0e3aacdb",                        [{"customdata":[[16,22],[45,6],[0,38],[26,11],[41,6],[48,5],[0,43],[0,38],[4,39],[3,45],[22,23],[20,28]],"hovertemplate":"tool=DNNMem\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DNNMem","marker":{"color":"#e41a1c","symbol":"circle","size":12},"mode":"markers","name":"DNNMem","orientation":"v","showlegend":true,"x":[42.10526315789473,88.23529411764706,0.0,70.27027027027027,87.2340425531915,90.56603773584906,0.0,0.0,9.30232558139535,6.25,48.888888888888886,41.66666666666667],"xaxis":"x","y":[7.03,25.28,6.2,17.12,17.34,26.29,7.11,5.48,3.99,3.95,18.36,14.78],"yaxis":"y","type":"scatter"},{"customdata":[[7,31],[19,32],[13,25],[7,30],[0,47],[11,42],[2,41],[7,31],[8,35],[3,45],[28,17],[21,27]],"hovertemplate":"tool=SchedTune\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SchedTune","marker":{"color":"#4daf4a","symbol":"diamond","size":12},"mode":"markers","name":"SchedTune","orientation":"v","showlegend":true,"x":[18.421052631578945,37.254901960784316,34.21052631578947,18.91891891891892,0.0,20.754716981132077,4.651162790697675,18.421052631578945,18.6046511627907,6.25,62.22222222222222,43.75],"xaxis":"x","y":[28.8,13.73,41.16,22.64,35.93,15.63,45.74,47.12,14.37,7.54,24.43,22.24],"yaxis":"y","type":"scatter"},{"customdata":[[2,36],[1,50],[0,38],[0,37],[0,47],[1,52],[0,43],[0,38],[1,42],[0,48],[7,38],[9,39]],"hovertemplate":"tool=xMem (this paper)\u003cbr\u003eFailed Estimation Probability  (%)=%{x}\u003cbr\u003eRelative Error (%)=%{y}\u003cbr\u003eCorrect_Estimation_False_Count=%{customdata[0]}\u003cbr\u003eCorrect_Estimation_True_Count=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"xMem (this paper)","marker":{"color":"#377eb8","symbol":"square","size":12},"mode":"markers","name":"xMem (this paper)","orientation":"v","showlegend":true,"x":[5.263157894736842,1.9607843137254901,0.0,0.0,0.0,1.8867924528301887,0.0,0.0,2.3255813953488373,0.0,15.555555555555555,18.75],"xaxis":"x","y":[6.71,3.53,0.75,3.24,3.69,1.44,6.41,7.65,3.76,3.93,15.89,12.32],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179 ...

# %%
e_plot.data_processing(project_base)
# Out:
#              model  batch_size  target_iteration optimiser  device  \
# 0        ResNet101         992                 3       SGD       1
# 1        ResNet101         992                 3       SGD       1
# 2        ResNet101         992                 3       SGD       1
# 3            VGG19         724                 3   Adagrad       1
# 4            VGG19         724                 3   Adagrad       1
# ...            ...         ...               ...       ...     ...
# 1582         VGG16         573                 3      Adam       0
# 1583         VGG16         573                 3      Adam       0
# 1584  RegNetX400MF         483                 3      Adam       1
# 1585  RegNetX400MF         483                 3      Adam       1
# 1586  RegNetX400MF         483                 3      Adam       1
#
#        input_size  zero_grad_mode  total_gpu_memory used_gpu_memory  \
# 0     [86, 86, 3]               0       12622168064            None
# 1     [86, 86, 3]               0       12622168064            None
# 2     [86, 86, 3]               0       12622168064            None
# 3     [86, 86, 3]               0       12622168064            None
# 4     [86, 86, 3]               0       12622168064            None
# ...           ...             ...               ...             ...
# 1582  [86, 86, 3]               1        8318222336            None
# 1583  [86, 86, 3]               1        8318222336            None
# 1584  [86, 86, 3]               0       12622168064            None
# 1585  [86, 86, 3]               0       12622168064            None
# 1586  [86, 86, 3]               0       12622168064            None
#
#                      gpu_name  ...  accurate_estimation   save_memory  \
# 0     NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
# 1     NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
# 2     NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
# 3     NVIDIA GeForce RTX 3060  ...                False  0.000000e+00
# 4     NVIDIA GeForce RTX 3060  ...                False  0.000000e+00
# ...                       ...  ...                  ...           ...
# 1582  NVIDIA GeForce RTX 4060  ...                 True  8.318222e+09
# 1583  NVIDIA GeForce RTX 4060  ...                 True  8.318222e+09
# 1584  NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
# 1585  NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
# 1586  NVIDIA GeForce RTX 3060  ...                 True  1.262217e+10
#
#             memory    oom       runtime       ground     error  real_oom  \
# 0     1.313685e+10   True    5956202980  12362711040  0.062619      True
# 1     1.266470e+10   True   29490559978  12362711040  0.024427      True
# 2     1.267099e+10   True  158076793588  12362711040  0.024936      True
# 3     1.075630e+10  False    4165248169  11756634112  0.085087      True
# 4     1.242563e+10  False   11127471384  11756634112  0.056903      True
# ...            ...    ...           ...          ...       ...       ...
# 1582  9.210692e+09   True    9372239704   7637827584  0.205931      True
# 1583  9.206497e+09   True   29799879900   7637827584  0.205382      True
# 1584  4.001827e+09  False     591534343   2887778304  0.385781     False
# 1585  2.680160e+09  False   16995964827   2887778304  0.071895     False
# 1586  2.606760e+09  False   40897211059   2887778304  0.097313     False
#
#       correct_estimation    color
# 0                   True  #4daf4a
# 1                   True  #377eb8
# 2                   True  #e41a1c
# 3                  False  #4daf4a
# 4                  False  #377eb8
# ...                  ...      ...
# 1582                True  #377eb8
# 1583                True  #e41a1c
# 1584                True  #4daf4a
# 1585                True  #377eb8
# 1586                True  #e41a1c
#
# [1587 rows x 25 columns]
